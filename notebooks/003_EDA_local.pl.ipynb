# %% [markdown]
# # EDA

# %% [markdown]
# Ta EDA jest zawężona do zakresu lokalnego regiony do promienia 5 km od punktu zainteresowania (Mierzęcice)

# %% [markdown]
# ## 1. Załaduj dane

# %%
# Standard imports
from typing import Tuple
import time

# Suppress future warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Third party imports
from haversine import haversine
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import seaborn as sns

# Local imports
from _csv_utils import data_timeplace, DataPathCleaningManager

# %%
data_path_manager = DataPathCleaningManager(data_timeplace)
combined_df = data_path_manager._load_cleaned_df(domain="combined")

# %%
offers_5km_df = combined_df[
    (combined_df["location"]["city"] == "będziński")
    | (combined_df["location"]["city"] == "Zawada")
].copy()

# %%
import pandas as pd

def rename_columns(df: pd.DataFrame, translations: dict) -> pd.DataFrame:
    """
    Rename columns in a DataFrame with a MultiIndex according to provided translations.

    Args:
    df (pd.DataFrame): The DataFrame whose columns are to be renamed.
    translations (dict): A dictionary mapping the old column names (as tuples) to the new ones.

    Returns:
    pd.DataFrame: A new DataFrame with columns renamed.
    """
    
    # Create a new MultiIndex with the translated column names
    new_columns = []
    for col in df.columns:
        # Translate the column if it is in the translations, else keep the original
        new_col = translations.get(col, col)
        new_columns.append(new_col)

    new_index = pd.MultiIndex.from_tuples(new_columns)
    
    # Assign the new MultiIndex to the DataFrame and return it
    df.columns = new_index
    return df

# Dictionary of translations provided
columns_translation = {
    ('listing', 'link'): ('ogłoszenie', 'link'),
    ('listing', 'title'): ('ogłoszenie', 'tytuł'),
    ('listing', 'summary_description'): ('ogłoszenie', 'krótki_opis'),
    ('listing', 'remote_service'): ('ogłoszenie', 'usługa_zdalna'),
    ('pricing', 'price'): ('wycena', 'cena'),
    ('pricing', 'rent'): ('wycena', 'czynsz'),
    ('pricing', 'total_rent'): ('wycena', 'czynsz_całkowity'),
    ('pricing', 'total_rent_sqm'): ('wycena', 'czynsz_za_metr'),
    ('pricing', 'deposit'): ('wycena', 'kaucja'),
    ('pricing', 'deposit_ratio'): ('wycena', 'proporcja_kaucji'),
    ('location', 'complete_address'): ('lokalizacja', 'pełny_adres'),
    ('location', 'street'): ('lokalizacja', 'ulica'),
    ('location', 'city'): ('lokalizacja', 'miasto'),
    ('location', 'voivodeship'): ('lokalizacja', 'województwo'),
    ('size', 'square_meters'): ('wielkość', 'metry_kwadratowe'),
    ('size', 'number_of_rooms'): ('wielkość', 'liczba_pokoi'),
    ('size', 'floor'): ('wielkość', 'piętro'),
    ('size', 'attic'): ('wielkość', 'strych'),
    ('size', 'building_floors'): ('wielkość', 'liczba_pięter_budynku'),
    ('legal_and_availability', 'available_from'): ('własność_i_dostępność', 'dostępne_od'),
    ('legal_and_availability', 'completion'): ('własność_i_dostępność', 'zakończenie_budowy'),
    ('legal_and_availability', 'ownership'): ('własność_i_dostępność', 'własność'),
    ('legal_and_availability', 'rent_to_students'): ('własność_i_dostępność', 'wynajem_dla_studentów'),
    ('type_and_year', 'building_type'): ('rodzaj_i_rocznik', 'typ_budynku'),
    ('type_and_year', 'build_year'): ('rodzaj_i_rocznik', 'rok_budowy'),
    ('amenities', 'elevator'): ('udogodnienia', 'winda'),
    ('amenities', 'parking_space'): ('udogodnienia', 'miejsce_parkingowe'),
    ('equipment', 'no_information'): ('wyposażenie', 'brak_informacji'),
    ('equipment', 'stove'): ('wyposażenie', 'kuchenka'),
    ('equipment', 'fridge'): ('wyposażenie', 'lodówka'),
    ('equipment', 'furniture'): ('wyposażenie', 'meble'),
    ('equipment', 'oven'): ('wyposażenie', 'piekarnik'),
    ('equipment', 'washing_machine'): ('wyposażenie', 'pralka'),
    ('equipment', 'TV'): ('wyposażenie', 'telewizor'),
    ('equipment', 'dishwasher'): ('wyposażenie', 'zmywarka'),
    ('media_types', 'no_information'): ('media_komunikacyjne', 'brak_informacji'),
    ('media_types', 'internet'): ('media_komunikacyjne', 'internet'),
    ('media_types', 'telephone'): ('media_komunikacyjne', 'telefon'),
    ('media_types', 'cable_TV'): ('media_komunikacyjne', 'telewizja_kablowa'),
    ('heating', 'no_information'): ('ogrzewanie', 'brak_informacji'),
    ('heating', 'electric'): ('ogrzewanie', 'elektryczne'),
    ('heating', 'gas'): ('ogrzewanie', 'gazowe'),
    ('heating', 'other'): ('ogrzewanie', 'inne'),
    ('heating', 'boiler_room'): ('ogrzewanie', 'kotłownia'),
    ('heating', 'district'): ('ogrzewanie', 'miejskie'),
    ('heating', 'tile_stove'): ('ogrzewanie', 'piec_kaflowy'),
    ('security', 'no_information'): ('bezpieczeństwo', 'brak_informacji'),
    ('security', 'intercom_or_video_intercom'): ('bezpieczeństwo', 'domofon_lub_wideodomofon'),
    ('security', 'anti_burglary_doors_or_windows'): ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'),
    ('security', 'monitoring_or_security'): ('bezpieczeństwo', 'monitoring_lub_ochrona'),
    ('security', 'anti_burglary_roller_blinds'): ('bezpieczeństwo', 'rolety_antywłamaniowe'),
    ('security', 'alarm_system'): ('bezpieczeństwo', 'system_alarmowy'),
    ('security', 'enclosed_area'): ('bezpieczeństwo', 'teren_ogrodzony'),
    ('windows', 'aluminum'): ('okna', 'aluminiowe'),
    ('windows', 'no_information'): ('okna', 'brak_informacji'),
    ('windows', 'wooden'): ('okna', 'drewniane'),
    ('windows', 'plastic'): ('okna', 'plastikowe'),
    ('building_material', 'concrete'): ('materiał_budowlany', 'beton'),
    ('building_material', 'aerated_concrete'): ('materiał_budowlany', 'beton_komórkowy'),
    ('building_material', 'no_information'): ('materiał_budowlany', 'brak_informacji'),
    ('building_material', 'brick'): ('materiał_budowlany', 'cegła'),
    ('building_material', 'wood'): ('materiał_budowlany', 'drewno'),
    ('building_material', 'other'): ('materiał_budowlany', 'inny'),
    ('building_material', 'lightweight_aggregate'): ('materiał_budowlany', 'keramzyt'),
    ('building_material', 'hollow_brick'): ('materiał_budowlany', 'pustak'),
    ('building_material', 'silicate'): ('materiał_budowlany', 'silikat'),
    ('building_material', 'large_panel'): ('materiał_budowlany', 'wielka_płyta'),
    ('building_material', 'reinforced_concrete'): ('materiał_budowlany', 'żelbet'),
    ('additional_information', 'no_information'): ('informacje_dodatkowe', 'brak_informacji'),
    ('additional_information', 'duplex'): ('informacje_dodatkowe', 'mieszkanie_dwupoziomowe'),
    ('additional_information', 'air_conditioning'): ('informacje_dodatkowe', 'klimatyzacja'),
    ('additional_information', 'separate_kitchen'): ('informacje_dodatkowe', 'oddzielna_kuchnia'),
    ('additional_information', 'basement'): ('informacje_dodatkowe', 'piwnica'),
    ('additional_information', 'utility_room'): ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'),
    ('additional_information', 'non_smokers_only'): ('informacje_dodatkowe', 'tylko_dla_niepalących'),
}

offers_5km_df = rename_columns(offers_5km_df, columns_translation)

offers_5km_df[('rodzaj_i_rocznik', 'typ_budynku')]= offers_5km_df[('rodzaj_i_rocznik', 'typ_budynku')].map({
    'detached_house': 'dom_wolnostojący',
    'apartment_building': 'budynek_mieszkalny',
    'block_of_flats': 'blok',
    'historic_apartment_building': 'kamienica',
    'terraced_house': 'szeregowiec',
    })

# %% [markdown]
# ## 2. Eksploracja danych

# %% [markdown]
# ### 2.1 Dane numeryczne

# %%
offers_5km_df.describe().rename(index={'count': 'liczba', 'mean': 'średnia', 'std': 'odchylenie standardowe'})
# Out:
#                              wycena                               \
#                                cena      czynsz czynsz_całkowity
# liczba                    33.000000   18.000000        33.000000
# średnia                 1744.848485  504.777778      2020.181818
# odchylenie standardowe   639.893161  251.790425       676.300666
# min                      690.000000    1.000000       690.000000
# 25%                     1300.000000  394.000000      1577.000000
# 50%                     1600.000000  510.000000      1950.000000
# 75%                     2000.000000  700.000000      2502.000000
# max                     3500.000000  850.000000      3500.000000
#
#                                                                      \
#                        czynsz_za_metr       kaucja proporcja_kaucji
# liczba                           33.0    25.000000        25.000000
# średnia                      47.58918  2544.000000         1.226400
# odchylenie standardowe      14.460784   941.775805         0.309433
# min                              25.0  1200.000000         0.670000
# 25%                              33.2  2000.000000         1.000000
# 50%                         50.870968  2500.000000         1.110000
# 75%                             56.25  3000.000000         1.500000
# max                              78.0  5000.000000         1.960000
#
#                                wielkość                         \
#                        metry_kwadratowe liczba_pokoi    piętro
# liczba                             33.0         33.0      31.0
# średnia                       43.666667     2.060606  1.677419
# odchylenie standardowe        13.628249      0.74747  1.375672
# min                                23.0          1.0       0.0
# 25%                                36.0          2.0       1.0
# 50%                                44.0          2.0       1.0
# 75%                                50.0          2.0       2.5
# max                                88.0          4.0       4.0
#
#                                              rodzaj_i_rocznik
#                        liczba_pięter_budynku       rok_budowy
# liczba                                  26.0        11.000000
# średnia                             3.307692      1992.363636
# odchylenie standardowe              0.928191        30.777501
# min                                      2.0      1929.000000
# 25%                                     2.25      1975.000000
# 50%                                      4.0      1983.000000
# 75%                                      4.0      2020.000000
# max                                      5.0      2023.000000

# %% [markdown]
# 11 piętro to piętra 10+

# %% [markdown]
# **Wnioski z danych numerycznych:**
#
# 1. **Oferty**<br>
# Znajdują się w promieniu `25km`<br>
# od `"Mierzęcice, Będziński, Śląskie"`, w pobliżu regionalnego lotniska międzynarodowego.<br>
# Całkowita liczba ofert wynosi `1106`.
# 2. **Średni Całkowity Czynsz**:<br>
# Mediana całkowitego czynszu wynosi `2200,00 PLN`.
# 3. **Zakres Czynszu i Odchylenie Standardowe**:<br>
# Całkowity czynsz waha się od minimum `500` do maksimum `19,001`, przy odchyleniu standardowym wynoszącym `1442,41`.<br>Równocześnie szeroki zakres i duże odchylenie standardowe wskazują na znaczną zmienność cen wynajmu.
# 4. **Rozmiar Nieruchomości:**<br>
# Średni rozmiar nieruchomości to około `49,74` metrów kwadratowych.<br>Najmniejsza nieruchomość ma `8` metrów kwadratowych, a największa `413` metrów kwadratowych.
# 5. **Rok Budowy**:<br>
# Nieruchomości w zestawieniu danych zostały zbudowane między `1893` a `2025`, przy medianie roku budowy `2011`.<br>Dane obejmują szeroki zakres wieku nieruchomości, od historycznych po nowoczesne konstrukcje.
# 6. **Informacje o na którym piętrze jest mieszkanie**:<br>Mediana pięter, na których znajdują się nieruchomości to `2` piętro, wśród nieruchomości mieszczącymi się od poziomu piwnicy (`-1`) do `10 i wyższych` pięter. Mediana dla semj liczby pięter w budynkach to około `4`, co sugeruje, że większość nieruchomości znajduje się w budynkach niskich lub średniowysokich.
# 7. **Koszt za Metr Kwadratowy**:<br>
# Średni koszt za metr kwadratowy wynosi `51,88 PLN`, przy cenach wahających się od tak niskich jak `2,71 PLN` do tak wysokich jak `138,89 PLN` za metr kwadratowy.

# %% [markdown]
# ### 2.2 Total rent

# %%
aesthetics_plots = {
	'title_size': 16,
    'y_and_x_label_size': 12,
	'fontweight': 'bold',
	'label_color': "#435672",
    "palette": "viridis",
    "figsize": {
        "multiplot": (15, 10),  # (width, height) in inches
        "singleplot": (8, 6),
        },
    }

def set_plot_aesthetics(ax, title=None, xlabel=None, ylabel=None, title_color="#435672", tick_color="#435672", fontweight='bold'):
    if title:
        ax.set_title(title, color=title_color, fontweight=fontweight)
    if xlabel:
        ax.set_xlabel(xlabel, fontweight=fontweight)
    if ylabel:
        ax.set_ylabel(ylabel, fontweight=fontweight)
    ax.tick_params(colors=tick_color, which='both')  # For both major and minor ticks
    ax.yaxis.label.set_color(tick_color)  # Y-axis label color
    ax.xaxis.label.set_color(tick_color)  # X-axis label color
    for spine in ax.spines.values():  # Spine color
        spine.set_edgecolor(tick_color)

def plot_distribution(data_series: pd.Series, title: str, kde_setting: bool, bin: int, x_ticks_number: int, x_ticks_rotation: bool):
    fig, ax = plt.subplots(figsize=aesthetics_plots['figsize']['singleplot'])

    cmap = plt.get_cmap('viridis')
    color = cmap(0.5)  # Using a single color, you can adjust this as needed

    sns.histplot(data_series, ax=ax, kde=kde_setting, bins=bin, color=color)
    set_plot_aesthetics(ax, title)

    ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=x_ticks_number))
    if x_ticks_rotation:
        ax.xaxis.set_major_locator(ticker.FixedLocator(ax.get_xticks()))
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

    plt.ylabel('częstotliwość')

    # Add annotations for each bar
    for p in ax.patches:
        # Calculate the percentage of the total
        percentage = (p.get_height() / len(data_series)) * 100
        # Place the annotation above the bar
        if percentage > 0:
            ax.annotate(f"{percentage:.1f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='bottom', fontsize=10, weight='bold', color=aesthetics_plots['label_color'], xytext=(0, 2),
                        textcoords='offset points')

    plt.tight_layout()
    plt.show()

# %%
def advanced_statistical_analysis(df: pd.DataFrame = offers_5km_df):
    price_data = df['wycena']['czynsz_całkowity']

    # Central Tendency Measures
    mean_price = price_data.mean()
    median_price = price_data.median()
    mode_price = price_data.mode()[0]

    # Variability Measures
    std_dev_price = price_data.std()
    variance_price = price_data.var()
    range_price = price_data.max() - price_data.min()
    iqr_price = np.percentile(price_data, 75) - np.percentile(price_data, 25)

    # Skewness and Kurtosis
    skewness_price = price_data.skew()
    kurtosis_price = price_data.kurtosis()

    # Quantile Analysis
    quantiles_price = price_data.quantile([0.25, 0.5, 0.75, 0.9, 0.95, 0.99])

    # Outlier Detection: Using the 1.5*IQR rule
    lower_bound = np.percentile(price_data, 25) - 1.5 * iqr_price
    upper_bound = np.percentile(price_data, 75) + 1.5 * iqr_price
    outliers_upper = price_data[(price_data >= upper_bound)].count()
    outliers_lower = price_data[(price_data <= lower_bound)].count()
    outlier_total = outliers_upper + outliers_lower
    outlier_data = price_data[(price_data <= lower_bound) | (price_data >= upper_bound)]

    advanced_statistics = {
        "Średnia": mean_price.round(2),
        "Mediana": median_price,
        "Odchylenie standardowe": std_dev_price.round(2),
        "Dominanta": mode_price,
        "Wariancja": variance_price.round(2),
        "Zakres": range_price,
        "Rozstęp międzykwartylowy (IQR)": iqr_price,
        "Skośność": skewness_price.round(2),
        "Kurtoza": kurtosis_price.round(2),
        "Kwantyle": quantiles_price,
        "Dolna granica wykrywania wartości odstających": lower_bound,
        "Górna granica wykrywania wartości odstających": upper_bound,
        "Liczba wartości poniżej dolnej granicy": outliers_upper,
        "Liczba wartości powyżej górnej granicy": outliers_lower,
        "Liczba wartości odstających": outlier_total,
        "Całkowita liczba ofert": price_data.count(),
        "Stosunek liczby wartości odstających do całkowitej liczby ofert": str((outlier_total / price_data.count()).round(2) * 100)+ "%",
    }

    print("Cena łączna, zaawansowane statystyki:")
    plot_distribution(outlier_data, 'Rozkład cen skrajnych', False, 30, 40, True)
    return advanced_statistics

advanced_statistical_analysis(offers_5km_df)
# Out:
# Cena łączna, zaawansowane statystyki:
# {'Średnia': 2020.18,
#  'Mediana': 1950.0,
#  'Odchylenie standardowe': 676.3,
#  'Dominanta': 2500.0,
#  'Wariancja': 457382.59,
#  'Zakres': 2810.0,
#  'Rozstęp międzykwartylowy (IQR)': 925.0,
#  'Skośność': 0.01,
#  'Kurtoza': -0.47,
#  'Kwantyle': 0.25    1577.0
#  0.50    1950.0
#  0.75    2502.0
#  0.90    2690.0
#  0.95    3020.0
#  0.99    3404.0
#  Name: czynsz_całkowity, dtype: float64,
#  'Dolna granica wykrywania wartości odstających': 189.5,
#  'Górna granica wykrywania wartości odstających': 3889.5,
#  'Liczba wartości poniżej dolnej granicy': 0,
#  'Liczba wartości powyżej górnej granicy': 0,
#  'Liczba wartości odstających': 0,
#  'Całkowita liczba ofert': 33,
#  'Stosunek liczby wartości odstających do całkowitej liczby ofert': '0.0%'}

# %% [markdown]
# **Wnioski z analizy cen wynajmu:**
#
# 1. **Tendencja cen wynajmu**:<br>
# Wiele czynszów jest bardziej przystępnych cenowo, podczas gdy tylko kilka jest naprawdę drogich.
#
# 1. **Wyjątkowe ceny wynajmu**:<br>
# Około `6%` cen wynajmu jest znacznie wyższych lub niższych od typowych.
# Te kilka nietypowych czynszów może sprawić, że średnia będzie wyglądać na wyższą niż to, co widzi większość ludzi.
#
# 1. **Zróżnicowanie cen wynajmu**:<br>
# Analizując dane dotyczące wynajmu, spektrum cen jest bardzo szerokie.<br>
# Większość wynajmów `(75%)` jest w przeciętnych cenach.<br>
# Jednak patrząc na ceny wyższe od przeciętnych ceny wynajmu znacząco rosną.<br>
# Górne `5%` nieruchomości mają czynsze znacznie wyższe od średniej,<br>
# a górne `1%` znajdują się w jeszcze bardziej ekskluzywnym przedziale cenowym.<br>

# %%
def plot_distribution(offers_5km_df: pd.DataFrame):
    fig, axes = plt.subplots(nrows=2, ncols=2, figsize=aesthetics_plots['figsize']['multiplot'])

    cmap = plt.get_cmap('viridis')
    colors = cmap(np.linspace(0, 1, 4))

    titles = ["Rozkład cen", "Rozkład rozmiarów", "Rozkład liczby pokoi", "Rozkład roku budowy"]
    data_columns = ['wycena.czynsz_całkowity', 'wielkość.metry_kwadratowe', 'wielkość.liczba_pokoi', 'rodzaj_i_rocznik.rok_budowy']
    kde_settings = [True, True, False, True]
    bins = [30, 30, 6, 30]

    for ax, title, color, data_column, kde_setting, bin in zip(axes.flat, titles, colors, data_columns, kde_settings, bins):
        sns.histplot(offers_5km_df[data_column.split('.')[0]][data_column.split('.')[1]].astype('float'), ax=ax, kde=kde_setting, bins=bin, color=color)
        ax.set_ylabel("liczba ofert")
        set_plot_aesthetics(ax, title)

    plt.tight_layout()
    plt.show()

plot_distribution(offers_5km_df)

# %% [markdown]
# **Wnioski z danych liczbowych:**
#
# 1. **Ceny wynajmu**:<br>
# Większość czynszów jest niska, z najczęszczą kwotą około `2500`. Nie ma zbyt wielu drogich mieszkań do wynajęcia.
#
# 2. **Wielkość mieszkań**:<br>
# Częstsze są mniejsze mieszkania (około `50 m2`) niż większe. Dużych apartamentów jest niewiele.
# Większość dostępnych mieszkań składa się z dwóch pomieszczeń dodatkowych poza kuchnią, łazienką oraz ewentualnym korytarzem.
#
# 1. **Wiek Budynków**:<br>
# Wiele budynków zostało wzniesionych około roku `1980`, a ostatnio obserwujemy wzrost nowych budowli od około `2020`.<br>
# Ogólnie widać brak starych budynków na rynku wynajmu.

# %%
def set_plot_aesthetics(ax, title=None, xlabel=None, ylabel=None, title_color="#435672", tick_color="#435672", fontweight='bold'):
    if title:
        ax.set_title(title, color=title_color, fontweight=fontweight)
    if xlabel:
        ax.set_xlabel(xlabel, fontweight=fontweight)
    if ylabel:
        ax.set_ylabel(ylabel, fontweight=fontweight)
    ax.tick_params(colors=tick_color, which='both')  # For both major and minor ticks
    ax.yaxis.label.set_color(tick_color)  # Y-axis label color
    ax.xaxis.label.set_color(tick_color)  # X-axis label color
    for spine in ax.spines.values():  # Spine color
        spine.set_edgecolor(tick_color)

def plot_distribution(offers_5km_df: pd.DataFrame):

    # No information about furniture delete
    # refactor

    # Calculate medians
    median_furnished = offers_5km_df[offers_5km_df['wyposażenie']['meble']]['wycena']['czynsz_całkowity'].median()
    median_unfurnished = offers_5km_df[~offers_5km_df['wyposażenie']['meble']]['wycena']['czynsz_całkowity'].median()
    
    median_furnished_sqm = (offers_5km_df[offers_5km_df['wyposażenie']['meble']]['wycena']['czynsz_za_metr']).median()
    median_unfurnished_sqm = (offers_5km_df[~offers_5km_df['wyposażenie']['meble']]['wycena']['czynsz_za_metr']).median()

    # Prepare data for plotting
    median_data_furnishing = pd.DataFrame({
        'Umeblowanie': ['Umeblowany', 'Nieumbelowany'],
        'Mediana czynszu': [median_furnished, median_unfurnished]
    })

    median_data_square_meter = pd.DataFrame({
        'Umeblowanie': ['Umeblowany', 'Nieumbelowany'],
        'Mediana czynszu za metr kwadratowy': [median_furnished_sqm, median_unfurnished_sqm]
    })

    title = 'Mediana czynszu i czynszu za metr kwadratowy umeblowanych\ni nieumeblowanych apartamentów'

    # Create a figure with two subplots
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=aesthetics_plots['figsize']['multiplot'])

    # Plotting Median Rent
    sns.barplot(x='Umeblowanie', y='Mediana czynszu', data=median_data_furnishing, ax=ax1, palette='viridis')

    # Plotting Median Czynsz per Square Meter
    sns.barplot(x='Umeblowanie', y='Mediana czynszu za metr kwadratowy', data=median_data_square_meter, ax=ax2, palette='viridis')

    for ax in [ax1, ax2]:
        for p in ax.patches:
            ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha='center', va='center', fontsize=9, color=aesthetics_plots["label_color"], fontweight='bold',
                        xytext=(0, 5),
                        textcoords='offset points')
            
    # Apply aesthetics to each subplot
    set_plot_aesthetics(ax1, title='Mediana czynszu', xlabel='Typ apartamentu', ylabel='Mediana czynszu')
    set_plot_aesthetics(ax2, title='Mediana czynszu za metr kwadratowy', xlabel='Typ apartamentu', ylabel='Mediana czynszu za metr')

    # Set the main title for the figure
    fig.suptitle(title, color="#435672", fontsize=aesthetics_plots['title_size'], fontweight='bold')


    plt.tight_layout()
    plt.show()

    print(f"Różnice median:")
    print(f"Umeblowane vs nieumeblowane: {abs(median_furnished - median_unfurnished)} PLN")
    print(f"Umeblowane vs nieumeblowane na metr kwadratowy: {(abs(median_furnished_sqm - median_unfurnished_sqm)).round()} PLN")

plot_distribution(offers_5km_df)
# Out:
# Różnice median:
# Umeblowane vs nieumeblowane: 536.0 PLN
# Umeblowane vs nieumeblowane na metr kwadratowy: 19.0 PLN

# %% [markdown]
# **Wnioski dotyczące cen mieszkań umeblowanych vs nieumeblowanych:**
#
# 1. **Wyższy czynsz za mieszkania umeblowane**:<br>
# Mieszkania umeblowane mają wyższy czynsz w porównaniu do nieumeblowanych o `340 PLN`.<br>
# Sugeruje to, że najemcy płacą więcej za dodatkową wygodę.
#
# 1. **Umeblowanie nieznacznie podnosi cenę**:<br>
# Różnica w cenie wynajmu za metr kwadratowy pomiędzy mieszkaniami umeblowanymi a nieumeblowanymi jest marginalna (`10 PLN`), co może oznaczać, że za umeblowanie płaci się niewielką dopłatę bez względu na rozmiar mieszkania.

# %%
def show_categorical_data_percentage_distribution(
        df: pd.DataFrame, 
        categorical_column: Tuple[str, str], 
        distribution_column: Tuple[str, str], 
        title: str,
        x_ticks_number: int = 10,
        y_ticks_number: int = 8,
        x_ticks_rotation: bool = True,
        y_ticks_rotation: bool = True,
    ):
    
    # Create a subset DataFrame with only the required columns
    plot_data = df[[categorical_column, distribution_column]].dropna()

    # Set up the matplotlib figure
    plt.figure(figsize=(14, 7))

    # Get unique building types from the categorical column
    building_types = plot_data[categorical_column].unique()

    # Generate a list of colors, one for each building type
    my_palette = ['#bfed2d'] + ['#00c37f'] + ["#007e90"] + ['#51006f'] + ["#FF9F66"]

    ax = plt.gca()  # Get the current Axes instance on the current figure matching the given keyword args, or create one.

    # Plot each building type's histogram
    for building_type, color in zip(building_types, my_palette):
        # Select the rows where the building type matches and is not null
        subset = plot_data[plot_data[categorical_column] == building_type]
        sns.histplot(subset[distribution_column], kde=False, color=color, label=building_type, ax=ax)

    
    # Add some formatting and titles
    x_axis_title = distribution_column[1].replace('_', ' ')

    plt.title(title, color=aesthetics_plots['label_color'], fontsize=aesthetics_plots['title_size'], weight=aesthetics_plots['fontweight'])
    plt.xlabel(x_axis_title, color=aesthetics_plots['label_color'], fontsize=aesthetics_plots['y_and_x_label_size'], weight=aesthetics_plots['fontweight'])
    plt.ylabel('częstotliwość', color=aesthetics_plots['label_color'], fontsize=aesthetics_plots['y_and_x_label_size'], weight=aesthetics_plots['fontweight'])

    legend = plt.legend(title=x_axis_title)
    plt.setp(legend.get_title(), fontsize='large', color=aesthetics_plots['label_color'], weight='bold')
    plt.setp(legend.get_texts(), color=aesthetics_plots['label_color'])

    # Customize x-axis ticks
    ax.xaxis.set_major_locator(ticker.MaxNLocator(nbins=x_ticks_number))
    ax.yaxis.set_major_locator(ticker.MaxNLocator(nbins=y_ticks_number))

    if x_ticks_rotation:
        ax.xaxis.set_major_locator(ticker.FixedLocator(ax.get_xticks()))
        ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
        
    if y_ticks_rotation:
        ax.yaxis.set_major_locator(ticker.FixedLocator(ax.get_yticks()))
        ax.set_yticklabels(ax.get_yticklabels(), rotation=45)

    plt.xticks(color=aesthetics_plots['label_color'])
    plt.yticks(color=aesthetics_plots['label_color'])
    
    sns.despine(right=True, top=True)

    # Add annotations for each bar
    for p in ax.patches:
        # Calculate the percentage of the total
        percentage = (p.get_height() / len(df)) * 100
        # Place the annotation above the bar
        if percentage > 0:
            ax.annotate(f"{percentage:.1f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='bottom', fontsize=10, color=aesthetics_plots['label_color'], xytext=(0, 8),
                        textcoords='offset points')

    # Show the plot
    plt.show()

# %%
show_categorical_data_percentage_distribution(
    offers_5km_df,  
    ('rodzaj_i_rocznik', 'typ_budynku'),
    ('wycena', 'czynsz_całkowity'),
    'Rozkład ceny całkowitej dla każdego typu budynku',
    x_ticks_number= 60,
    x_ticks_rotation= True
    )

# %% [markdown]
# **Wnioski z rozkładu cen każdego typu budynku**:
#
# 1. **Budynki Mieszkalne**:<br>
# Ceny mieszkań w budynkach mieszkalnych wahają się od `400` do `8000` PLN, z większością ofert skupionych w przedziale od `400` do `3.200` PLN. Większość ofert jest dostępna w przystępnej cenie, co jest korzystne dla osób z ograniczonym budżetem.
#
# 1. **Bloki Mieszkalne**:<br>
# Ceny w blokach mieszkalnych wykazują różnorodność, z cenami mieszkań rozciągającymi się od `800` do `3.600` PLN, przy okazjonalnych ofertach w wyższej cenie (`4.800` do `5.000` PLN).
#
# 1. **Kamienice**:<br>
# W historycznych kamienicach ceny mieszkań obejmują szeroki zakres – od `400` do `3.600` PLN, z kilkoma apartamentami w wyższym segmencie cenowym (`4.000`, `5.600`, `6.000`, `8.000` PLN).

# %%
show_categorical_data_percentage_distribution(
    offers_5km_df,  
    ('rodzaj_i_rocznik', 'typ_budynku'),
    ('wycena', 'czynsz_za_metr'),
    'Rozkład całkowitej ceny za metr dla każdego typu budynku',
    x_ticks_number= 40,
    x_ticks_rotation= True
    )

# %% [markdown]
# **Wnioski z cen za metr kwadratowy na podstawie różnych typów budynków**:
#
# 1. **Cena za Metr w Budynkach Mieszkalnych**:<br>
# W budynkach mieszkalnych cena za metr kwadratowy zazwyczaj wynosi około `50` PLN. Jest to najczęściej spotykany przedział cenowy w tej kategorii.
#
# 1. **Cena za Metr w Historycznych Kamienicach**:<br>
# W historycznych kamienicach ceny za metr kwadratowy są bardziej zróżnicowane. Większość ofert koncentruje się w niższych i wyższych zakresach cenowych, z wyraźnym skupieniem wokół `24` PLN za m².
#
# 1. **Cena za Metr w Domach Szeregowych**:<br>
# Chociaż domy szeregowe są rzadziej spotykane, to oferują one większą przestrzeń za niższą cenę za metr kwadratowy, z przedziałem cenowym przeważnie od `4` do `24` PLN za m². To wskazuje na korzystniejsze warunki dla szukających przestronniejszych mieszkań za umiarkowaną cenę.

# %%
def plot_distribution(offers_5km_df: pd.DataFrame):

    # Calculation with handling of potential division by zero or NaN values
    plot_data = offers_5km_df['wycena']['czynsz_za_metr']
    plot_data = plot_data.dropna().round().astype('float')

    cmap = plt.get_cmap('viridis')
    colors = cmap(np.linspace(0, 1, 4))
    color = colors[0]
    title = 'Rozkład cen za metr kwadratowy'

    fig, ax = plt.subplots(figsize=aesthetics_plots['figsize']['singleplot'])
    hist = sns.histplot(plot_data, kde=True, bins=30, color=color, ax=ax)
    ax.set_xlabel('Cena za metr kwadratowy')
    ax.set_ylabel('Częstotliwość')

    for p in hist.patches:
        bin_center = p.get_x() + p.get_width() / 2
        ax.annotate(f'{bin_center:.1f}', (bin_center, p.get_height()), 
                    ha='center', va='center', fontsize=9, color=aesthetics_plots["label_color"], xytext=(0, 5),
                    textcoords='offset points')
        
    set_plot_aesthetics(ax, title)

    plt.tight_layout()
    plt.show()

plot_distribution(offers_5km_df)

# %% [markdown]
# **Wnioski cena za metr kwadratowy**:
#
# 1. **Powszechne ceny wynajmu**:<br>
# Większość mieszkań kosztuje około `50` PLN za każdy metr kwadratowy.<br>
# Rzadziej spotyka się mieszkania, za które pobiera się wyższą opłatę za metr kwadratowy.
#
# 1. **Niewiele mieszkań z wyższą stawką**:<br>
# Diagram wskazuje, że choć istnieją pojedyncze mieszkania z wyjątkowo wysoką ceną za metr kwadratowy,
# są one stosunkowo rzadkie. Większość ofert utrzymuje się w standardowym zakresie cen.

# %%
CategoryResults = list[Tuple[str, str, float]]

def get_correlations(data: pd.DataFrame):
    
    def get_correlation_category(bottom_threshold: float, upper_threshold: float = 1.0):

        category_results: CategoryResults = []
        num_columns = len(columns)

        for i in range(num_columns):
            for j in range(i+1, num_columns):

                corr_value = correlations.iloc[i, j]
                col_left = columns[i]
                col_right = columns[j]

                category_results = add_correlation_value(
                        bottom_threshold, 
                        upper_threshold, 
                        category_results, 
                        corr_value, 
                        col_left, 
                        col_right
                    )
        
        sorted_results = sorted(category_results, key=lambda x: x[2], reverse=True)
        return sorted_results

    def add_correlation_value(
                bottom_threshold: float, 
                upper_threshold: float, 
                category_results: CategoryResults, 
                corr_value: float, 
                col_left: str, 
                col_right: str
            ):

        if upper_threshold == 1.0:
            if bottom_threshold <= abs(corr_value):
                category_results.append((col_left, col_right, corr_value))
        else:
            if bottom_threshold <= abs(corr_value) < upper_threshold:
                category_results.append((col_left, col_right, corr_value))

        return category_results
    
    correlations = data.corr()
    columns = correlations.columns
    correlations_results = {}
    
    correlations_results['Silna korelacja'] = get_correlation_category(bottom_threshold = 0.7)
    correlations_results['Przeciętna korelacja'] = get_correlation_category(bottom_threshold = 0.3, upper_threshold = 0.7)
    correlations_results['Słaba korelacja'] = get_correlation_category(bottom_threshold = 0.1, upper_threshold = 0.3)

    return correlations_results

def print_results(correlations_results: dict[str, CategoryResults]):

    for level, results in correlations_results.items():
        print(f"\n{level}:")
        for col_left, col_right, corr_value in results:
            print(f"{col_left} - {col_right}: {round(corr_value, 2)}")
        print("\r")

def print_correlations(data: pd.DataFrame):
    
    correlations_results = get_correlations(data)
    
    print_results(correlations_results)

def get_top_extreme_results(correlations_results: dict[str, CategoryResults], column_of_interest: str, num_positive_negative: int):

    top_positive = []

    positive_count = 0

    for _, results in correlations_results.items():

        for col_left, col_right, corr_value in results:

            if corr_value > 0:

                correlation_cols = [col_left, col_right]

                if column_of_interest in correlation_cols:

                    if positive_count == num_positive_negative:
                        break

                    corr_item = (col_left, col_right, corr_value)

                    top_positive.append(corr_item)

                    positive_count += 1

        if positive_count == num_positive_negative:
            break

    top_negative = []

    negative_count = 0

    reversed_dict = dict(reversed(correlations_results.items()))

    for _, results in reversed_dict.items():

        for col_left, col_right, corr_value in results:

            if corr_value < 0:

                correlation_cols = [col_left, col_right]

                if column_of_interest in correlation_cols:

                    if negative_count == num_positive_negative:
                        break

                    corr_item = (col_left, col_right, corr_value)

                    top_negative.insert(0, corr_item)

                    negative_count += 1

        if negative_count == num_positive_negative:
            break

    top_positive.extend(top_negative)

    return top_positive

# %%
def show_extreme_correlations(data: pd.DataFrame, column_of_interest: Tuple[str, str], num_results: int = 5, title: str = "Add title"):

    columns_to_drop = [('wycena', 'cena'), ('wycena', 'czynsz')]
    data = data.drop(columns=columns_to_drop)
    correlations_results = get_correlations(data)
    extreme_correlations = get_top_extreme_results(correlations_results, column_of_interest, num_results)

    unique_elements = list(
        set([item[0] for item in extreme_correlations] + [item[1] for item in extreme_correlations])
    )
    correlation_values = np.zeros((len(unique_elements), len(unique_elements)))

    element_index_mapping = {
        element: index for index, element in enumerate(unique_elements)
    }

    for item in extreme_correlations:
        col1, col2, corr_value = item
        row_index = element_index_mapping[col2]
        col_index = element_index_mapping[col1]
        correlation_values[row_index, col_index] = corr_value

    df = pd.DataFrame(correlation_values, index=unique_elements, columns=unique_elements)
    df_column_of_interest = df[[column_of_interest]]
    df_no_empty_value = df_column_of_interest.drop(index=column_of_interest)
    df_no_0 = df_no_empty_value.drop(df_no_empty_value[df_no_empty_value.eq(0).all(axis=1)].index)
    df_plot = df_no_0.sort_values(by=column_of_interest, ascending=False)

    with plt.style.context('seaborn'):
        plt.figure(figsize=aesthetics_plots['figsize']['singleplot'])
        heatmap = sns.heatmap(df_plot, cmap='coolwarm', vmin = -1.0, vmax = 1.0, annot=True, fmt=".2f", annot_kws={'color': "white", 'fontweight': "bold"}, cbar=True, cbar_kws={"label": "Correlation"})
        # set color palette proportional to values 1.0 is always max 0.0 always least color value
        heatmap.set_xlabel("")
        heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0, color=aesthetics_plots['label_color'])
        heatmap.set_xticklabels([])
        
        # Add the following lines
        cbar = heatmap.collections[0].colorbar
        cbar.set_ticks([heatmap.collections[0].get_array().min(), heatmap.collections[0].get_array().max()])
        cbar.set_ticks([-1.0, 0, 1.0])  # Set the tick locations
        cbar.set_ticklabels(['-1.0', '0.0', '1.0'])  # Set the tick labelss
        cbar.ax.yaxis.set_ticklabels(cbar.ax.yaxis.get_ticklabels(), color=aesthetics_plots['label_color'])  # Set the tick label color
        cbar.set_label("Korelacja", color=aesthetics_plots['label_color'])
        
        plt.title(f'Korelacja: {title}\n', color=aesthetics_plots['label_color'], fontsize = aesthetics_plots['title_size'], weight=aesthetics_plots['fontweight'])
        plt.show()

# %%
show_extreme_correlations(offers_5km_df, ('wycena', 'czynsz_całkowity'), num_results = 10, title="Cena całkowita")

# %% [markdown]
# **Wnioski z korelacji ceny całkowitej**:
#
# 1. **Związek między kaucją a ceną wynajmu**:<br>
# Istnieje silna dodatnia zależność między wysokością kaucji a całkowitą ceną, wskazując na korelację wynoszącą `0.86`.<br>
# Sugeruje to, że droższe oferty wynajmu zazwyczaj wymagają wyższej kaucji.
#
# 1. **Wielkość ma znaczenie**:<br>
# Rozmiar mieszkania, mierzony w metrach kwadratowych, ma istotną dodatnią korelację (`0.54`) z całkowitą ceną,<br>
# Liczba pokoi również wykazuje dodatnią korelację (`0.46`) z ceną, choć nie jest ona tak silna jak w przypadku wielkości w metrach kwadratowych,<br>co wskazuje, że ogólny rozmiar może mieć większy wpływ na cenę niż sama liczba pokoi.
#
# 1. **Brak Informacji, a inne cechy**:<br>
# Mieszkania z dodatkami, takimi jak klimatyzacja, mają tendencję do wyższych cen, co potwierdza korelacja `0.38`.<br>
# Z kolei oferty z mniejszą ilością informacji lub ich brakiem często są nieco tańsze – tu korelacja wynosi (`-0.15`). Może to oznaczać, że mniej kosztowne oferty często są mniej szczegółowo opisane.

# %% [markdown]
# Inne korelacje:

# %%
print_correlations(offers_5km_df)
# Out:
# Silna korelacja:
# ('materiał_budowlany', 'beton_komórkowy') - ('informacje_dodatkowe', 'klimatyzacja'): 1.0
# ('wycena', 'cena') - ('wycena', 'czynsz_całkowity'): 0.89
# ('rodzaj_i_rocznik', 'rok_budowy') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.88
# ('wyposażenie', 'kuchenka') - ('wyposażenie', 'lodówka'): 0.87
# ('wyposażenie', 'meble') - ('wyposażenie', 'pralka'): 0.82
# ('media_komunikacyjne', 'internet') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.81
# ('udogodnienia', 'winda') - ('materiał_budowlany', 'pustak'): 0.8
# ('wyposażenie', 'kuchenka') - ('wyposażenie', 'meble'): 0.8
# ('wyposażenie', 'lodówka') - ('wyposażenie', 'meble'): 0.8
# ('wyposażenie', 'kuchenka') - ('wyposażenie', 'piekarnik'): 0.78
# ('wyposażenie', 'kuchenka') - ('wyposażenie', 'pralka'): 0.75
# ('wyposażenie', 'lodówka') - ('wyposażenie', 'pralka'): 0.75
# ('udogodnienia', 'winda') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.75
# ('wycena', 'czynsz') - ('rodzaj_i_rocznik', 'rok_budowy'): 0.73
# ('wycena', 'czynsz_za_metr') - ('rodzaj_i_rocznik', 'rok_budowy'): 0.71
# ('wielkość', 'liczba_pięter_budynku') - ('ogrzewanie', 'miejskie'): 0.7
# ('wyposażenie', 'brak_informacji') - ('wyposażenie', 'pralka'): -0.71
# ('media_komunikacyjne', 'brak_informacji') - ('media_komunikacyjne', 'telewizja_kablowa'): -0.76
# ('wyposażenie', 'brak_informacji') - ('wyposażenie', 'kuchenka'): -0.81
# ('wyposażenie', 'brak_informacji') - ('wyposażenie', 'lodówka'): -0.81
# ('wyposażenie', 'brak_informacji') - ('wyposażenie', 'meble'): -0.87
# ('media_komunikacyjne', 'brak_informacji') - ('media_komunikacyjne', 'internet'): -0.94
# ('bezpieczeństwo', 'brak_informacji') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): -0.94
# ('okna', 'brak_informacji') - ('okna', 'plastikowe'): -1.0
#
#
# Przeciętna korelacja:
# ('bezpieczeństwo', 'rolety_antywłamaniowe') - ('bezpieczeństwo', 'system_alarmowy'): 0.7
# ('bezpieczeństwo', 'rolety_antywłamaniowe') - ('materiał_budowlany', 'beton_komórkowy'): 0.7
# ('bezpieczeństwo', 'rolety_antywłamaniowe') - ('informacje_dodatkowe', 'klimatyzacja'): 0.7
# ('bezpieczeństwo', 'system_alarmowy') - ('materiał_budowlany', 'pustak'): 0.7
# ('ogrzewanie', 'gazowe') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.68
# ('udogodnienia', 'miejsce_parkingowe') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.68
# ('wycena', 'cena') - ('udogodnienia', 'miejsce_parkingowe'): 0.68
# ('wycena', 'czynsz_całkowity') - ('wycena', 'kaucja'): 0.68
# ('wyposażenie', 'lodówka') - ('wyposażenie', 'piekarnik'): 0.65
# ('wyposażenie', 'kuchenka') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.65
# ('wyposażenie', 'lodówka') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.65
# ('wycena', 'cena') - ('wielkość', 'metry_kwadratowe'): 0.65
# ('wyposażenie', 'piekarnik') - ('wyposażenie', 'pralka'): 0.64
# ('wycena', 'kaucja') - ('rodzaj_i_rocznik', 'rok_budowy'): 0.62
# ('media_komunikacyjne', 'internet') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.62
# ('ogrzewanie', 'gazowe') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.62
# ('media_komunikacyjne', 'brak_informacji') - ('bezpieczeństwo', 'brak_informacji'): 0.61
# ('wycena', 'czynsz_całkowity') - ('udogodnienia', 'miejsce_parkingowe'): 0.61
# ('media_komunikacyjne', 'internet') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.61
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.6
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.6
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('materiał_budowlany', 'pustak'): 0.6
# ('wyposażenie', 'meble') - ('wyposażenie', 'piekarnik'): 0.6
# ('wycena', 'kaucja') - ('wycena', 'proporcja_kaucji'): 0.6
# ('media_komunikacyjne', 'telewizja_kablowa') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.59
# ('wyposażenie', 'piekarnik') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.59
# ('wycena', 'cena') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.59
# ('rodzaj_i_rocznik', 'rok_budowy') - ('ogrzewanie', 'gazowe'): 0.59
# ('wycena', 'czynsz_całkowity') - ('wielkość', 'metry_kwadratowe'): 0.58
# ('rodzaj_i_rocznik', 'rok_budowy') - ('udogodnienia', 'winda'): 0.58
# ('wycena', 'czynsz') - ('informacje_dodatkowe', 'piwnica'): 0.58
# ('wielkość', 'metry_kwadratowe') - ('udogodnienia', 'miejsce_parkingowe'): 0.57
# ('udogodnienia', 'winda') - ('bezpieczeństwo', 'system_alarmowy'): 0.56
# ('wielkość', 'metry_kwadratowe') - ('wielkość', 'liczba_pokoi'): 0.56
# ('wyposażenie', 'zmywarka') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.55
# ('wyposażenie', 'zmywarka') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.55
# ('ogrzewanie', 'miejskie') - ('materiał_budowlany', 'wielka_płyta'): 0.55
# ('udogodnienia', 'miejsce_parkingowe') - ('ogrzewanie', 'gazowe'): 0.55
# ('wycena', 'czynsz_całkowity') - ('wycena', 'czynsz_za_metr'): 0.55
# ('wielkość', 'piętro') - ('wielkość', 'liczba_pięter_budynku'): 0.55
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.54
# ('udogodnienia', 'miejsce_parkingowe') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.54
# ('media_komunikacyjne', 'telefon') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.53
# ('wycena', 'czynsz_całkowity') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.53
# ('wielkość', 'piętro') - ('materiał_budowlany', 'wielka_płyta'): 0.52
# ('wycena', 'kaucja') - ('wielkość', 'liczba_pokoi'): 0.52
# ('wyposażenie', 'pralka') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.52
# ('materiał_budowlany', 'wielka_płyta') - ('informacje_dodatkowe', 'piwnica'): 0.52
# ('wycena', 'czynsz') - ('wycena', 'czynsz_całkowity'): 0.51
# ('wyposażenie', 'piekarnik') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.51
# ('wycena', 'cena') - ('wycena', 'kaucja'): 0.5
# ('rodzaj_i_rocznik', 'rok_budowy') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.49
# ('wyposażenie', 'pralka') - ('wyposażenie', 'telewizor'): 0.49
# ('wyposażenie', 'pralka') - ('wyposażenie', 'zmywarka'): 0.49
# ('wycena', 'cena') - ('wielkość', 'liczba_pokoi'): 0.48
# ('media_komunikacyjne', 'brak_informacji') - ('informacje_dodatkowe', 'brak_informacji'): 0.48
# ('ogrzewanie', 'gazowe') - ('bezpieczeństwo', 'system_alarmowy'): 0.48
# ('ogrzewanie', 'gazowe') - ('materiał_budowlany', 'beton_komórkowy'): 0.48
# ('ogrzewanie', 'gazowe') - ('informacje_dodatkowe', 'klimatyzacja'): 0.48
# ('wielkość', 'liczba_pokoi') - ('ogrzewanie', 'gazowe'): 0.47
# ('wyposażenie', 'meble') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.47
# ('bezpieczeństwo', 'rolety_antywłamaniowe') - ('materiał_budowlany', 'pustak'): 0.47
# ('bezpieczeństwo', 'teren_ogrodzony') - ('materiał_budowlany', 'pustak'): 0.47
# ('rodzaj_i_rocznik', 'rok_budowy') - ('wyposażenie', 'zmywarka'): 0.47
# ('udogodnienia', 'miejsce_parkingowe') - ('wyposażenie', 'zmywarka'): 0.47
# ('ogrzewanie', 'miejskie') - ('informacje_dodatkowe', 'piwnica'): 0.46
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('informacje_dodatkowe', 'piwnica'): 0.46
# ('wyposażenie', 'lodówka') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.46
# ('wyposażenie', 'kuchenka') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.46
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.46
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.46
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.46
# ('wyposażenie', 'zmywarka') - ('media_komunikacyjne', 'internet'): 0.45
# ('informacje_dodatkowe', 'pomieszczenie_gospodarcze') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.45
# ('wielkość', 'piętro') - ('ogrzewanie', 'miejskie'): 0.45
# ('wycena', 'cena') - ('udogodnienia', 'winda'): 0.45
# ('wycena', 'czynsz_całkowity') - ('rodzaj_i_rocznik', 'rok_budowy'): 0.45
# ('rodzaj_i_rocznik', 'rok_budowy') - ('materiał_budowlany', 'pustak'): 0.45
# ('wycena', 'kaucja') - ('wyposażenie', 'zmywarka'): 0.45
# ('wyposażenie', 'zmywarka') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.45
# ('wyposażenie', 'zmywarka') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.45
# ('wycena', 'kaucja') - ('wielkość', 'metry_kwadratowe'): 0.44
# ('rodzaj_i_rocznik', 'rok_budowy') - ('wyposażenie', 'meble'): 0.44
# ('rodzaj_i_rocznik', 'rok_budowy') - ('wyposażenie', 'pralka'): 0.44
# ('wyposażenie', 'lodówka') - ('media_komunikacyjne', 'internet'): 0.44
# ('wyposażenie', 'kuchenka') - ('media_komunikacyjne', 'internet'): 0.44
# ('wyposażenie', 'zmywarka') - ('ogrzewanie', 'gazowe'): 0.44
# ('wyposażenie', 'zmywarka') - ('media_komunikacyjne', 'telefon'): 0.44
# ('media_komunikacyjne', 'telewizja_kablowa') - ('informacje_dodatkowe', 'piwnica'): 0.44
# ('rodzaj_i_rocznik', 'rok_budowy') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.44
# ('wycena', 'czynsz_całkowity') - ('wielkość', 'liczba_pokoi'): 0.43
# ('media_komunikacyjne', 'telefon') - ('materiał_budowlany', 'brak_informacji'): 0.43
# ('wyposażenie', 'kuchenka') - ('wyposażenie', 'zmywarka'): 0.43
# ('wyposażenie', 'kuchenka') - ('wyposażenie', 'telewizor'): 0.43
# ('wyposażenie', 'lodówka') - ('wyposażenie', 'zmywarka'): 0.43
# ('wycena', 'czynsz_za_metr') - ('wyposażenie', 'meble'): 0.42
# ('wycena', 'czynsz_całkowity') - ('wyposażenie', 'zmywarka'): 0.42
# ('udogodnienia', 'winda') - ('informacje_dodatkowe', 'brak_informacji'): 0.42
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('materiał_budowlany', 'beton_komórkowy'): 0.42
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('informacje_dodatkowe', 'klimatyzacja'): 0.42
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('bezpieczeństwo', 'system_alarmowy'): 0.42
# ('materiał_budowlany', 'beton_komórkowy') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.42
# ('informacje_dodatkowe', 'klimatyzacja') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.42
# ('media_komunikacyjne', 'telewizja_kablowa') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.42
# ('wielkość', 'liczba_pięter_budynku') - ('materiał_budowlany', 'wielka_płyta'): 0.42
# ('wielkość', 'piętro') - ('wyposażenie', 'telewizor'): 0.41
# ('wielkość', 'liczba_pokoi') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.41
# ('wycena', 'czynsz_za_metr') - ('materiał_budowlany', 'pustak'): 0.41
# ('wyposażenie', 'piekarnik') - ('wyposażenie', 'telewizor'): 0.41
# ('wyposażenie', 'piekarnik') - ('wyposażenie', 'zmywarka'): 0.41
# ('wyposażenie', 'telewizor') - ('ogrzewanie', 'miejskie'): 0.41
# ('wycena', 'czynsz') - ('wyposażenie', 'zmywarka'): 0.41
# ('wycena', 'cena') - ('ogrzewanie', 'gazowe'): 0.4
# ('wyposażenie', 'meble') - ('wyposażenie', 'telewizor'): 0.4
# ('wyposażenie', 'meble') - ('wyposażenie', 'zmywarka'): 0.4
# ('wyposażenie', 'telewizor') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): 0.4
# ('media_komunikacyjne', 'telefon') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.4
# ('wyposażenie', 'brak_informacji') - ('bezpieczeństwo', 'brak_informacji'): 0.4
# ('udogodnienia', 'winda') - ('udogodnienia', 'miejsce_parkingowe'): 0.4
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.4
# ('wycena', 'czynsz_za_metr') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.4
# ('wyposażenie', 'pralka') - ('media_komunikacyjne', 'internet'): 0.39
# ('wyposażenie', 'lodówka') - ('informacje_dodatkowe', 'piwnica'): 0.39
# ('wycena', 'czynsz_za_metr') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.39
# ('wyposażenie', 'piekarnik') - ('ogrzewanie', 'miejskie'): 0.39
# ('wyposażenie', 'brak_informacji') - ('ogrzewanie', 'brak_informacji'): 0.39
# ('wielkość', 'liczba_pokoi') - ('udogodnienia', 'miejsce_parkingowe'): 0.39
# ('wyposażenie', 'pralka') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.39
# ('wycena', 'cena') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.39
# ('wyposażenie', 'brak_informacji') - ('informacje_dodatkowe', 'brak_informacji'): 0.39
# ('wyposażenie', 'kuchenka') - ('okna', 'plastikowe'): 0.38
# ('wycena', 'czynsz_całkowity') - ('ogrzewanie', 'gazowe'): 0.38
# ('rodzaj_i_rocznik', 'rok_budowy') - ('wyposażenie', 'kuchenka'): 0.38
# ('rodzaj_i_rocznik', 'rok_budowy') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.38
# ('wycena', 'czynsz_za_metr') - ('wyposażenie', 'pralka'): 0.38
# ('udogodnienia', 'miejsce_parkingowe') - ('materiał_budowlany', 'beton_komórkowy'): 0.38
# ('udogodnienia', 'miejsce_parkingowe') - ('informacje_dodatkowe', 'klimatyzacja'): 0.38
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('materiał_budowlany', 'beton_komórkowy'): 0.38
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('informacje_dodatkowe', 'klimatyzacja'): 0.38
# ('udogodnienia', 'miejsce_parkingowe') - ('bezpieczeństwo', 'system_alarmowy'): 0.38
# ('ogrzewanie', 'inne') - ('materiał_budowlany', 'cegła'): 0.38
# ('media_komunikacyjne', 'internet') - ('informacje_dodatkowe', 'piwnica'): 0.37
# ('wyposażenie', 'pralka') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.36
# ('wycena', 'czynsz_całkowity') - ('udogodnienia', 'winda'): 0.36
# ('udogodnienia', 'winda') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.36
# ('udogodnienia', 'winda') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.36
# ('bezpieczeństwo', 'teren_ogrodzony') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.36
# ('materiał_budowlany', 'inny') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.36
# ('ogrzewanie', 'gazowe') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.36
# ('media_komunikacyjne', 'telefon') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.36
# ('wyposażenie', 'piekarnik') - ('media_komunikacyjne', 'telefon'): 0.36
# ('media_komunikacyjne', 'telefon') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.36
# ('ogrzewanie', 'gazowe') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.36
# ('wycena', 'czynsz_za_metr') - ('wycena', 'kaucja'): 0.36
# ('wycena', 'kaucja') - ('udogodnienia', 'miejsce_parkingowe'): 0.36
# ('wycena', 'czynsz_całkowity') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.36
# ('wyposażenie', 'kuchenka') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.36
# ('wyposażenie', 'lodówka') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.36
# ('wyposażenie', 'piekarnik') - ('media_komunikacyjne', 'internet'): 0.36
# ('wyposażenie', 'piekarnik') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): 0.36
# ('wyposażenie', 'brak_informacji') - ('media_komunikacyjne', 'brak_informacji'): 0.35
# ('wyposażenie', 'zmywarka') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.35
# ('wycena', 'czynsz_za_metr') - ('wyposażenie', 'zmywarka'): 0.35
# ('ogrzewanie', 'brak_informacji') - ('okna', 'brak_informacji'): 0.35
# ('wycena', 'czynsz_za_metr') - ('wyposażenie', 'telewizor'): 0.34
# ('wyposażenie', 'piekarnik') - ('informacje_dodatkowe', 'piwnica'): 0.34
# ('rodzaj_i_rocznik', 'rok_budowy') - ('okna', 'plastikowe'): 0.34
# ('wyposażenie', 'telewizor') - ('materiał_budowlany', 'wielka_płyta'): 0.34
# ('wycena', 'cena') - ('wycena', 'czynsz_za_metr'): 0.34
# ('materiał_budowlany', 'pustak') - ('informacje_dodatkowe', 'brak_informacji'): 0.34
# ('media_komunikacyjne', 'internet') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.34
# ('rodzaj_i_rocznik', 'rok_budowy') - ('materiał_budowlany', 'brak_informacji'): 0.33
# ('udogodnienia', 'miejsce_parkingowe') - ('okna', 'brak_informacji'): 0.33
# ('rodzaj_i_rocznik', 'rok_budowy') - ('ogrzewanie', 'brak_informacji'): 0.33
# ('rodzaj_i_rocznik', 'rok_budowy') - ('media_komunikacyjne', 'telefon'): 0.33
# ('rodzaj_i_rocznik', 'rok_budowy') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.33
# ('wielkość', 'metry_kwadratowe') - ('okna', 'brak_informacji'): 0.33
# ('rodzaj_i_rocznik', 'rok_budowy') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.33
# ('wielkość', 'metry_kwadratowe') - ('wyposażenie', 'brak_informacji'): 0.32
# ('wycena', 'cena') - ('bezpieczeństwo', 'system_alarmowy'): 0.32
# ('wycena', 'czynsz_za_metr') - ('udogodnienia', 'winda'): 0.32
# ('bezpieczeństwo', 'brak_informacji') - ('informacje_dodatkowe', 'brak_informacji'): 0.32
# ('rodzaj_i_rocznik', 'rok_budowy') - ('wyposażenie', 'lodówka'): 0.32
# ('wyposażenie', 'lodówka') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.32
# ('wyposażenie', 'kuchenka') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.32
# ('wycena', 'cena') - ('rodzaj_i_rocznik', 'rok_budowy'): 0.32
# ('wycena', 'cena') - ('wyposażenie', 'zmywarka'): 0.32
# ('wyposażenie', 'pralka') - ('ogrzewanie', 'gazowe'): 0.32
# ('wyposażenie', 'pralka') - ('media_komunikacyjne', 'telefon'): 0.32
# ('wycena', 'czynsz_całkowity') - ('wyposażenie', 'pralka'): 0.31
# ('wyposażenie', 'zmywarka') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.31
# ('wyposażenie', 'zmywarka') - ('materiał_budowlany', 'beton_komórkowy'): 0.31
# ('wyposażenie', 'zmywarka') - ('informacje_dodatkowe', 'klimatyzacja'): 0.31
# ('wyposażenie', 'zmywarka') - ('bezpieczeństwo', 'system_alarmowy'): 0.31
# ('rodzaj_i_rocznik', 'rok_budowy') - ('materiał_budowlany', 'beton_komórkowy'): 0.31
# ('rodzaj_i_rocznik', 'rok_budowy') - ('informacje_dodatkowe', 'klimatyzacja'): 0.31
# ('wycena', 'czynsz') - ('wielkość', 'metry_kwadratowe'): 0.31
# ('media_komunikacyjne', 'internet') - ('materiał_budowlany', 'wielka_płyta'): 0.31
# ('wyposażenie', 'piekarnik') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.31
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.31
# ('udogodnienia', 'miejsce_parkingowe') - ('media_komunikacyjne', 'telefon'): 0.31
# ('ogrzewanie', 'gazowe') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.31
# ('media_komunikacyjne', 'telefon') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.31
# ('okna', 'brak_informacji') - ('materiał_budowlany', 'brak_informacji'): 0.3
# ('wycena', 'proporcja_kaucji') - ('materiał_budowlany', 'cegła'): 0.3
# ('ogrzewanie', 'brak_informacji') - ('materiał_budowlany', 'brak_informacji'): 0.3
# ('wyposażenie', 'pralka') - ('ogrzewanie', 'brak_informacji'): -0.3
# ('wycena', 'czynsz_za_metr') - ('wielkość', 'metry_kwadratowe'): -0.3
# ('okna', 'plastikowe') - ('materiał_budowlany', 'brak_informacji'): -0.3
# ('wyposażenie', 'meble') - ('media_komunikacyjne', 'brak_informacji'): -0.31
# ('media_komunikacyjne', 'brak_informacji') - ('bezpieczeństwo', 'teren_ogrodzony'): -0.32
# ('wycena', 'czynsz_całkowity') - ('bezpieczeństwo', 'brak_informacji'): -0.32
# ('informacje_dodatkowe', 'brak_informacji') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): -0.32
# ('rodzaj_i_rocznik', 'rok_budowy') - ('wyposażenie', 'brak_informacji'): -0.32
# ('wyposażenie', 'brak_informacji') - ('media_komunikacyjne', 'internet'): -0.32
# ('rodzaj_i_rocznik', 'rok_budowy') - ('ogrzewanie', 'miejskie'): -0.32
# ('wielkość', 'piętro') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): -0.33
# ('rodzaj_i_rocznik', 'rok_budowy') - ('materiał_budowlany', 'wielka_płyta'): -0.33
# ('rodzaj_i_rocznik', 'rok_budowy') - ('informacje_dodatkowe', 'piwnica'): -0.33
# ('wielkość', 'metry_kwadratowe') - ('okna', 'plastikowe'): -0.33
# ('udogodnienia', 'miejsce_parkingowe') - ('ogrzewanie', 'miejskie'): -0.33
# ('ogrzewanie', 'miejskie') - ('materiał_budowlany', 'cegła'): -0.33
# ('wyposażenie', 'piekarnik') - ('materiał_budowlany', 'cegła'): -0.33
# ('udogodnienia', 'miejsce_parkingowe') - ('okna', 'plastikowe'): -0.33
# ('wielkość', 'metry_kwadratowe') - ('ogrzewanie', 'brak_informacji'): -0.33
# ('media_komunikacyjne', 'telefon') - ('bezpieczeństwo', 'brak_informacji'): -0.34
# ('ogrzewanie', 'gazowe') - ('bezpieczeństwo', 'brak_informacji'): -0.34
# ('rodzaj_i_rocznik', 'rok_budowy') - ('okna', 'brak_informacji'): -0.34
# ('wielkość', 'metry_kwadratowe') - ('rodzaj_i_rocznik', 'rok_budowy'): -0.34
# ('wyposażenie', 'brak_informacji') - ('wyposażenie', 'zmywarka'): -0.35
# ('wyposażenie', 'brak_informacji') - ('wyposażenie', 'telewizor'): -0.35
# ('ogrzewanie', 'brak_informacji') - ('materiał_budowlany', 'wielka_płyta'): -0.35
# ('wycena', 'cena') - ('ogrzewanie', 'brak_informacji'): -0.35
# ('ogrzewanie', 'brak_informacji') - ('okna', 'plastikowe'): -0.35
# ('wielkość', 'piętro') - ('udogodnienia', 'miejsce_parkingowe'): -0.35
# ('wycena', 'kaucja') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.35
# ('wyposażenie', 'piekarnik') - ('ogrzewanie', 'brak_informacji'): -0.36
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('informacje_dodatkowe', 'piwnica'): -0.36
# ('materiał_budowlany', 'brak_informacji') - ('informacje_dodatkowe', 'piwnica'): -0.36
# ('wycena', 'czynsz_całkowity') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.37
# ('wycena', 'czynsz_całkowity') - ('ogrzewanie', 'brak_informacji'): -0.37
# ('wyposażenie', 'brak_informacji') - ('media_komunikacyjne', 'telewizja_kablowa'): -0.38
# ('wielkość', 'liczba_pokoi') - ('wielkość', 'piętro'): -0.38
# ('wyposażenie', 'kuchenka') - ('okna', 'brak_informacji'): -0.38
# ('ogrzewanie', 'gazowe') - ('ogrzewanie', 'miejskie'): -0.38
# ('bezpieczeństwo', 'brak_informacji') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): -0.39
# ('wyposażenie', 'lodówka') - ('ogrzewanie', 'brak_informacji'): -0.39
# ('wyposażenie', 'kuchenka') - ('ogrzewanie', 'brak_informacji'): -0.39
# ('wyposażenie', 'meble') - ('bezpieczeństwo', 'brak_informacji'): -0.39
# ('wyposażenie', 'pralka') - ('materiał_budowlany', 'cegła'): -0.39
# ('informacje_dodatkowe', 'brak_informacji') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.39
# ('rodzaj_i_rocznik', 'rok_budowy') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.4
# ('wyposażenie', 'meble') - ('informacje_dodatkowe', 'brak_informacji'): -0.4
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('informacje_dodatkowe', 'brak_informacji'): -0.4
# ('wyposażenie', 'piekarnik') - ('informacje_dodatkowe', 'brak_informacji'): -0.4
# ('materiał_budowlany', 'brak_informacji') - ('materiał_budowlany', 'cegła'): -0.4
# ('wielkość', 'piętro') - ('ogrzewanie', 'gazowe'): -0.41
# ('wyposażenie', 'piekarnik') - ('media_komunikacyjne', 'brak_informacji'): -0.41
# ('wyposażenie', 'zmywarka') - ('media_komunikacyjne', 'brak_informacji'): -0.41
# ('bezpieczeństwo', 'brak_informacji') - ('informacje_dodatkowe', 'piwnica'): -0.41
# ('materiał_budowlany', 'wielka_płyta') - ('informacje_dodatkowe', 'brak_informacji'): -0.43
# ('bezpieczeństwo', 'brak_informacji') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): -0.43
# ('wyposażenie', 'meble') - ('ogrzewanie', 'brak_informacji'): -0.43
# ('media_komunikacyjne', 'brak_informacji') - ('informacje_dodatkowe', 'piwnica'): -0.44
# ('media_komunikacyjne', 'internet') - ('informacje_dodatkowe', 'brak_informacji'): -0.44
# ('wyposażenie', 'pralka') - ('media_komunikacyjne', 'brak_informacji'): -0.44
# ('wyposażenie', 'pralka') - ('bezpieczeństwo', 'brak_informacji'): -0.45
# ('wyposażenie', 'piekarnik') - ('bezpieczeństwo', 'brak_informacji'): -0.45
# ('media_komunikacyjne', 'brak_informacji') - ('media_komunikacyjne', 'telefon'): -0.46
# ('media_komunikacyjne', 'telewizja_kablowa') - ('informacje_dodatkowe', 'brak_informacji'): -0.46
# ('wycena', 'czynsz_za_metr') - ('wyposażenie', 'brak_informacji'): -0.47
# ('wyposażenie', 'kuchenka') - ('informacje_dodatkowe', 'brak_informacji'): -0.48
# ('wyposażenie', 'lodówka') - ('informacje_dodatkowe', 'brak_informacji'): -0.48
# ('wyposażenie', 'lodówka') - ('media_komunikacyjne', 'brak_informacji'): -0.48
# ('wyposażenie', 'kuchenka') - ('media_komunikacyjne', 'brak_informacji'): -0.48
# ('materiał_budowlany', 'brak_informacji') - ('materiał_budowlany', 'wielka_płyta'): -0.49
# ('wielkość', 'liczba_pięter_budynku') - ('materiał_budowlany', 'cegła'): -0.49
# ('wyposażenie', 'brak_informacji') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): -0.5
# ('wielkość', 'liczba_pięter_budynku') - ('ogrzewanie', 'gazowe'): -0.5
# ('wyposażenie', 'pralka') - ('informacje_dodatkowe', 'brak_informacji'): -0.5
# ('wycena', 'czynsz') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.5
# ('wyposażenie', 'zmywarka') - ('bezpieczeństwo', 'brak_informacji'): -0.52
# ('media_komunikacyjne', 'telewizja_kablowa') - ('bezpieczeństwo', 'brak_informacji'): -0.56
# ('media_komunikacyjne', 'internet') - ('bezpieczeństwo', 'brak_informacji'): -0.56
# ('wyposażenie', 'lodówka') - ('bezpieczeństwo', 'brak_informacji'): -0.58
# ('wyposażenie', 'kuchenka') - ('bezpieczeństwo', 'brak_informacji'): -0.58
# ('media_komunikacyjne', 'brak_informacji') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): -0.58
# ('wycena', 'proporcja_kaucji') - ('rodzaj_i_rocznik', 'rok_budowy'): -0.59
# ('rodzaj_i_rocznik', 'rok_budowy') - ('bezpieczeństwo', 'brak_informacji'): -0.59
# ('wyposażenie', 'brak_informacji') - ('wyposażenie', 'piekarnik'): -0.63
# ('ogrzewanie', 'brak_informacji') - ('ogrzewanie', 'miejskie'): -0.63
# ('informacje_dodatkowe', 'brak_informacji') - ('informacje_dodatkowe', 'piwnica'): -0.65
# ('media_komunikacyjne', 'brak_informacji') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): -0.66
# ('rodzaj_i_rocznik', 'rok_budowy') - ('ogrzewanie', 'elektryczne'): -0.68
# ('rodzaj_i_rocznik', 'rok_budowy') - ('materiał_budowlany', 'cegła'): -0.68
#
#
# Słaba korelacja:
# ('rodzaj_i_rocznik', 'rok_budowy') - ('udogodnienia', 'miejsce_parkingowe'): 0.3
# ('wielkość', 'metry_kwadratowe') - ('ogrzewanie', 'elektryczne'): 0.3
# ('wyposażenie', 'meble') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.3
# ('media_komunikacyjne', 'internet') - ('media_komunikacyjne', 'telefon'): 0.3
# ('media_komunikacyjne', 'internet') - ('ogrzewanie', 'gazowe'): 0.3
# ('wycena', 'czynsz_całkowity') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.3
# ('wycena', 'czynsz_za_metr') - ('wielkość', 'liczba_pięter_budynku'): 0.3
# ('ogrzewanie', 'gazowe') - ('materiał_budowlany', 'pustak'): 0.29
# ('media_komunikacyjne', 'telefon') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.29
# ('ogrzewanie', 'gazowe') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.29
# ('wyposażenie', 'telewizor') - ('okna', 'plastikowe'): 0.29
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.29
# ('wycena', 'czynsz_całkowity') - ('media_komunikacyjne', 'internet'): 0.29
# ('wyposażenie', 'meble') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.29
# ('media_komunikacyjne', 'telewizja_kablowa') - ('materiał_budowlany', 'wielka_płyta'): 0.29
# ('wycena', 'czynsz_całkowity') - ('media_komunikacyjne', 'telefon'): 0.29
# ('wycena', 'czynsz_za_metr') - ('wyposażenie', 'kuchenka'): 0.29
# ('wielkość', 'piętro') - ('informacje_dodatkowe', 'piwnica'): 0.29
# ('wycena', 'cena') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.28
# ('wycena', 'cena') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.28
# ('wyposażenie', 'zmywarka') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.28
# ('wycena', 'czynsz') - ('udogodnienia', 'miejsce_parkingowe'): 0.28
# ('rodzaj_i_rocznik', 'rok_budowy') - ('media_komunikacyjne', 'internet'): 0.28
# ('rodzaj_i_rocznik', 'rok_budowy') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.28
# ('wyposażenie', 'kuchenka') - ('ogrzewanie', 'gazowe'): 0.28
# ('wyposażenie', 'lodówka') - ('media_komunikacyjne', 'telefon'): 0.28
# ('wyposażenie', 'lodówka') - ('ogrzewanie', 'gazowe'): 0.28
# ('wyposażenie', 'kuchenka') - ('media_komunikacyjne', 'telefon'): 0.28
# ('wyposażenie', 'lodówka') - ('wyposażenie', 'telewizor'): 0.28
# ('wielkość', 'liczba_pokoi') - ('media_komunikacyjne', 'internet'): 0.28
# ('media_komunikacyjne', 'telewizja_kablowa') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.28
# ('ogrzewanie', 'elektryczne') - ('bezpieczeństwo', 'brak_informacji'): 0.28
# ('rodzaj_i_rocznik', 'rok_budowy') - ('bezpieczeństwo', 'system_alarmowy'): 0.28
# ('wyposażenie', 'kuchenka') - ('ogrzewanie', 'miejskie'): 0.28
# ('wyposażenie', 'lodówka') - ('ogrzewanie', 'miejskie'): 0.28
# ('wielkość', 'liczba_pięter_budynku') - ('udogodnienia', 'winda'): 0.27
# ('wyposażenie', 'pralka') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.27
# ('wycena', 'proporcja_kaucji') - ('ogrzewanie', 'brak_informacji'): 0.27
# ('wycena', 'czynsz_za_metr') - ('wyposażenie', 'lodówka'): 0.27
# ('wycena', 'cena') - ('media_komunikacyjne', 'telefon'): 0.27
# ('wycena', 'czynsz') - ('wyposażenie', 'brak_informacji'): 0.27
# ('wyposażenie', 'meble') - ('media_komunikacyjne', 'internet'): 0.27
# ('media_komunikacyjne', 'brak_informacji') - ('okna', 'brak_informacji'): 0.27
# ('wyposażenie', 'kuchenka') - ('informacje_dodatkowe', 'piwnica'): 0.27
# ('wyposażenie', 'telewizor') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.27
# ('wyposażenie', 'piekarnik') - ('materiał_budowlany', 'wielka_płyta'): 0.27
# ('wyposażenie', 'meble') - ('media_komunikacyjne', 'telefon'): 0.26
# ('wyposażenie', 'meble') - ('ogrzewanie', 'gazowe'): 0.26
# ('wyposażenie', 'meble') - ('okna', 'plastikowe'): 0.26
# ('ogrzewanie', 'brak_informacji') - ('bezpieczeństwo', 'brak_informacji'): 0.26
# ('wycena', 'czynsz') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.26
# ('wycena', 'kaucja') - ('wyposażenie', 'pralka'): 0.26
# ('wycena', 'cena') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.25
# ('ogrzewanie', 'elektryczne') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.25
# ('bezpieczeństwo', 'rolety_antywłamaniowe') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.25
# ('bezpieczeństwo', 'teren_ogrodzony') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.25
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.25
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('materiał_budowlany', 'pustak'): 0.25
# ('wyposażenie', 'piekarnik') - ('materiał_budowlany', 'inny'): 0.25
# ('ogrzewanie', 'miejskie') - ('materiał_budowlany', 'inny'): 0.25
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.25
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('materiał_budowlany', 'inny'): 0.25
# ('wycena', 'czynsz') - ('media_komunikacyjne', 'telefon'): 0.25
# ('wyposażenie', 'pralka') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.25
# ('media_komunikacyjne', 'telefon') - ('informacje_dodatkowe', 'piwnica'): 0.24
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('okna', 'plastikowe'): 0.24
# ('ogrzewanie', 'brak_informacji') - ('informacje_dodatkowe', 'brak_informacji'): 0.24
# ('materiał_budowlany', 'brak_informacji') - ('informacje_dodatkowe', 'brak_informacji'): 0.24
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.24
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.24
# ('wyposażenie', 'pralka') - ('informacje_dodatkowe', 'piwnica'): 0.24
# ('wyposażenie', 'brak_informacji') - ('materiał_budowlany', 'cegła'): 0.24
# ('wycena', 'proporcja_kaucji') - ('okna', 'brak_informacji'): 0.24
# ('wycena', 'kaucja') - ('ogrzewanie', 'gazowe'): 0.24
# ('udogodnienia', 'miejsce_parkingowe') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.24
# ('wyposażenie', 'kuchenka') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.24
# ('wyposażenie', 'lodówka') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.24
# ('ogrzewanie', 'miejskie') - ('okna', 'plastikowe'): 0.24
# ('wyposażenie', 'piekarnik') - ('okna', 'plastikowe'): 0.24
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('okna', 'plastikowe'): 0.24
# ('wyposażenie', 'kuchenka') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): 0.24
# ('media_komunikacyjne', 'internet') - ('okna', 'plastikowe'): 0.24
# ('wycena', 'kaucja') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.24
# ('bezpieczeństwo', 'system_alarmowy') - ('informacje_dodatkowe', 'brak_informacji'): 0.23
# ('media_komunikacyjne', 'internet') - ('materiał_budowlany', 'beton_komórkowy'): 0.23
# ('media_komunikacyjne', 'internet') - ('informacje_dodatkowe', 'klimatyzacja'): 0.23
# ('ogrzewanie', 'inne') - ('informacje_dodatkowe', 'brak_informacji'): 0.23
# ('wycena', 'czynsz_całkowity') - ('bezpieczeństwo', 'system_alarmowy'): 0.23
# ('wielkość', 'liczba_pięter_budynku') - ('wyposażenie', 'telewizor'): 0.23
# ('wycena', 'czynsz_całkowity') - ('wyposażenie', 'piekarnik'): 0.23
# ('wyposażenie', 'zmywarka') - ('informacje_dodatkowe', 'piwnica'): 0.23
# ('wycena', 'cena') - ('wyposażenie', 'pralka'): 0.23
# ('wielkość', 'metry_kwadratowe') - ('materiał_budowlany', 'cegła'): 0.23
# ('wycena', 'kaucja') - ('media_komunikacyjne', 'internet'): 0.23
# ('wielkość', 'liczba_pokoi') - ('bezpieczeństwo', 'system_alarmowy'): 0.23
# ('materiał_budowlany', 'wielka_płyta') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): 0.23
# ('wycena', 'czynsz_za_metr') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.23
# ('wycena', 'czynsz') - ('wyposażenie', 'lodówka'): 0.22
# ('wycena', 'czynsz_za_metr') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.22
# ('okna', 'brak_informacji') - ('informacje_dodatkowe', 'brak_informacji'): 0.22
# ('wyposażenie', 'lodówka') - ('okna', 'plastikowe'): 0.22
# ('wyposażenie', 'meble') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.22
# ('wycena', 'czynsz_całkowity') - ('wyposażenie', 'meble'): 0.22
# ('wycena', 'czynsz') - ('media_komunikacyjne', 'internet'): 0.22
# ('wielkość', 'liczba_pokoi') - ('media_komunikacyjne', 'telefon'): 0.22
# ('wycena', 'czynsz') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.22
# ('wycena', 'czynsz_za_metr') - ('media_komunikacyjne', 'internet'): 0.22
# ('wielkość', 'liczba_pięter_budynku') - ('materiał_budowlany', 'inny'): 0.22
# ('media_komunikacyjne', 'brak_informacji') - ('materiał_budowlany', 'cegła'): 0.22
# ('okna', 'plastikowe') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.22
# ('wycena', 'cena') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.22
# ('wyposażenie', 'pralka') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.22
# ('wyposażenie', 'pralka') - ('materiał_budowlany', 'pustak'): 0.22
# ('wyposażenie', 'pralka') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.22
# ('wyposażenie', 'pralka') - ('materiał_budowlany', 'inny'): 0.22
# ('wielkość', 'metry_kwadratowe') - ('ogrzewanie', 'gazowe'): 0.22
# ('wyposażenie', 'meble') - ('informacje_dodatkowe', 'piwnica'): 0.22
# ('media_komunikacyjne', 'brak_informacji') - ('ogrzewanie', 'brak_informacji'): 0.22
# ('wycena', 'czynsz_za_metr') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.22
# ('wyposażenie', 'meble') - ('ogrzewanie', 'miejskie'): 0.21
# ('wycena', 'czynsz_całkowity') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.21
# ('wycena', 'proporcja_kaucji') - ('bezpieczeństwo', 'brak_informacji'): 0.21
# ('wycena', 'czynsz_całkowity') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.21
# ('udogodnienia', 'miejsce_parkingowe') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.21
# ('udogodnienia', 'miejsce_parkingowe') - ('ogrzewanie', 'elektryczne'): 0.21
# ('udogodnienia', 'miejsce_parkingowe') - ('materiał_budowlany', 'pustak'): 0.21
# ('ogrzewanie', 'elektryczne') - ('materiał_budowlany', 'cegła'): 0.21
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.21
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('materiał_budowlany', 'inny'): 0.21
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('materiał_budowlany', 'pustak'): 0.21
# ('media_komunikacyjne', 'internet') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.21
# ('media_komunikacyjne', 'internet') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.21
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('informacje_dodatkowe', 'brak_informacji'): 0.21
# ('ogrzewanie', 'miejskie') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): 0.21
# ('udogodnienia', 'winda') - ('ogrzewanie', 'gazowe'): 0.21
# ('ogrzewanie', 'gazowe') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.21
# ('wycena', 'czynsz_całkowity') - ('materiał_budowlany', 'inny'): 0.21
# ('media_komunikacyjne', 'brak_informacji') - ('ogrzewanie', 'elektryczne'): 0.2
# ('wycena', 'czynsz_całkowity') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.2
# ('bezpieczeństwo', 'brak_informacji') - ('materiał_budowlany', 'brak_informacji'): 0.2
# ('wycena', 'czynsz') - ('wycena', 'kaucja'): 0.2
# ('bezpieczeństwo', 'brak_informacji') - ('materiał_budowlany', 'cegła'): 0.2
# ('wyposażenie', 'pralka') - ('materiał_budowlany', 'wielka_płyta'): 0.2
# ('media_komunikacyjne', 'internet') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.2
# ('wielkość', 'liczba_pięter_budynku') - ('informacje_dodatkowe', 'piwnica'): 0.2
# ('wielkość', 'liczba_pokoi') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.19
# ('ogrzewanie', 'inne') - ('bezpieczeństwo', 'brak_informacji'): 0.19
# ('wycena', 'cena') - ('materiał_budowlany', 'pustak'): 0.19
# ('wycena', 'czynsz') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.19
# ('wycena', 'czynsz') - ('materiał_budowlany', 'beton_komórkowy'): 0.19
# ('wycena', 'czynsz') - ('informacje_dodatkowe', 'klimatyzacja'): 0.19
# ('ogrzewanie', 'gazowe') - ('okna', 'plastikowe'): 0.19
# ('wycena', 'czynsz_za_metr') - ('wyposażenie', 'piekarnik'): 0.19
# ('wycena', 'cena') - ('okna', 'brak_informacji'): 0.19
# ('wyposażenie', 'kuchenka') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.19
# ('wyposażenie', 'kuchenka') - ('materiał_budowlany', 'pustak'): 0.19
# ('wyposażenie', 'lodówka') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.19
# ('wyposażenie', 'lodówka') - ('materiał_budowlany', 'pustak'): 0.19
# ('wyposażenie', 'lodówka') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.19
# ('wyposażenie', 'kuchenka') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.19
# ('wyposażenie', 'lodówka') - ('materiał_budowlany', 'inny'): 0.19
# ('wyposażenie', 'kuchenka') - ('materiał_budowlany', 'inny'): 0.19
# ('wycena', 'czynsz_za_metr') - ('bezpieczeństwo', 'system_alarmowy'): 0.19
# ('wyposażenie', 'pralka') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.19
# ('media_komunikacyjne', 'brak_informacji') - ('materiał_budowlany', 'brak_informacji'): 0.19
# ('media_komunikacyjne', 'telewizja_kablowa') - ('ogrzewanie', 'gazowe'): 0.19
# ('wycena', 'cena') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.19
# ('wycena', 'czynsz_całkowity') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.19
# ('wielkość', 'metry_kwadratowe') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.19
# ('wycena', 'cena') - ('media_komunikacyjne', 'internet'): 0.19
# ('media_komunikacyjne', 'telewizja_kablowa') - ('ogrzewanie', 'miejskie'): 0.19
# ('udogodnienia', 'miejsce_parkingowe') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.19
# ('wyposażenie', 'brak_informacji') - ('okna', 'brak_informacji'): 0.18
# ('wycena', 'czynsz_całkowity') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.18
# ('wycena', 'czynsz_całkowity') - ('materiał_budowlany', 'beton_komórkowy'): 0.18
# ('wycena', 'czynsz_całkowity') - ('informacje_dodatkowe', 'klimatyzacja'): 0.18
# ('wyposażenie', 'meble') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.18
# ('wyposażenie', 'meble') - ('materiał_budowlany', 'pustak'): 0.18
# ('wyposażenie', 'meble') - ('materiał_budowlany', 'inny'): 0.18
# ('wyposażenie', 'meble') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.18
# ('ogrzewanie', 'elektryczne') - ('okna', 'brak_informacji'): 0.18
# ('materiał_budowlany', 'inny') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): 0.18
# ('wyposażenie', 'zmywarka') - ('materiał_budowlany', 'wielka_płyta'): 0.18
# ('wyposażenie', 'telewizor') - ('wyposażenie', 'zmywarka'): 0.18
# ('wyposażenie', 'piekarnik') - ('ogrzewanie', 'gazowe'): 0.17
# ('wycena', 'cena') - ('materiał_budowlany', 'inny'): 0.17
# ('wycena', 'czynsz_całkowity') - ('wyposażenie', 'lodówka'): 0.17
# ('wyposażenie', 'piekarnik') - ('bezpieczeństwo', 'system_alarmowy'): 0.17
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('materiał_budowlany', 'beton_komórkowy'): 0.17
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('informacje_dodatkowe', 'klimatyzacja'): 0.17
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('bezpieczeństwo', 'system_alarmowy'): 0.17
# ('wielkość', 'metry_kwadratowe') - ('media_komunikacyjne', 'telefon'): 0.17
# ('wyposażenie', 'meble') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.17
# ('okna', 'plastikowe') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.16
# ('wycena', 'czynsz_za_metr') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.16
# ('wyposażenie', 'brak_informacji') - ('materiał_budowlany', 'brak_informacji'): 0.16
# ('wielkość', 'liczba_pokoi') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.16
# ('wielkość', 'liczba_pokoi') - ('wyposażenie', 'piekarnik'): 0.16
# ('wyposażenie', 'telewizor') - ('media_komunikacyjne', 'internet'): 0.16
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.16
# ('wielkość', 'piętro') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.16
# ('wielkość', 'metry_kwadratowe') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.16
# ('materiał_budowlany', 'brak_informacji') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.16
# ('informacje_dodatkowe', 'piwnica') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.16
# ('wycena', 'czynsz') - ('ogrzewanie', 'miejskie'): 0.15
# ('wyposażenie', 'pralka') - ('okna', 'plastikowe'): 0.15
# ('wycena', 'czynsz_całkowity') - ('materiał_budowlany', 'pustak'): 0.15
# ('wycena', 'czynsz_całkowity') - ('wyposażenie', 'kuchenka'): 0.15
# ('wycena', 'czynsz_za_metr') - ('ogrzewanie', 'gazowe'): 0.15
# ('wycena', 'cena') - ('wyposażenie', 'piekarnik'): 0.15
# ('wyposażenie', 'telewizor') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.15
# ('wyposażenie', 'zmywarka') - ('materiał_budowlany', 'pustak'): 0.15
# ('wyposażenie', 'telewizor') - ('materiał_budowlany', 'inny'): 0.15
# ('wyposażenie', 'telewizor') - ('materiał_budowlany', 'pustak'): 0.15
# ('wyposażenie', 'zmywarka') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.15
# ('wyposażenie', 'pralka') - ('materiał_budowlany', 'beton_komórkowy'): 0.15
# ('wyposażenie', 'pralka') - ('informacje_dodatkowe', 'klimatyzacja'): 0.15
# ('wyposażenie', 'pralka') - ('bezpieczeństwo', 'system_alarmowy'): 0.15
# ('wielkość', 'liczba_pokoi') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.15
# ('wielkość', 'liczba_pokoi') - ('materiał_budowlany', 'inny'): 0.15
# ('media_komunikacyjne', 'telewizja_kablowa') - ('okna', 'plastikowe'): 0.15
# ('ogrzewanie', 'miejskie') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.15
# ('wycena', 'czynsz_za_metr') - ('wielkość', 'piętro'): 0.15
# ('materiał_budowlany', 'brak_informacji') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.15
# ('wycena', 'czynsz_za_metr') - ('ogrzewanie', 'inne'): 0.15
# ('wycena', 'proporcja_kaucji') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.15
# ('wyposażenie', 'pralka') - ('ogrzewanie', 'miejskie'): 0.15
# ('wycena', 'proporcja_kaucji') - ('wielkość', 'piętro'): 0.15
# ('media_komunikacyjne', 'telefon') - ('ogrzewanie', 'gazowe'): 0.15
# ('wycena', 'kaucja') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): 0.15
# ('wielkość', 'liczba_pokoi') - ('wyposażenie', 'zmywarka'): 0.15
# ('wyposażenie', 'pralka') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): 0.15
# ('okna', 'plastikowe') - ('informacje_dodatkowe', 'piwnica'): 0.15
# ('wycena', 'kaucja') - ('wyposażenie', 'piekarnik'): 0.14
# ('wyposażenie', 'kuchenka') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.14
# ('wyposażenie', 'lodówka') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.14
# ('wielkość', 'liczba_pięter_budynku') - ('wyposażenie', 'piekarnik'): 0.14
# ('wycena', 'proporcja_kaucji') - ('media_komunikacyjne', 'brak_informacji'): 0.14
# ('udogodnienia', 'miejsce_parkingowe') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.14
# ('wyposażenie', 'piekarnik') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.14
# ('media_komunikacyjne', 'brak_informacji') - ('bezpieczeństwo', 'system_alarmowy'): 0.14
# ('media_komunikacyjne', 'brak_informacji') - ('ogrzewanie', 'inne'): 0.14
# ('wielkość', 'liczba_pięter_budynku') - ('okna', 'brak_informacji'): 0.14
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): 0.14
# ('wycena', 'kaucja') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.14
# ('wycena', 'cena') - ('wielkość', 'liczba_pięter_budynku'): 0.14
# ('wycena', 'czynsz_za_metr') - ('okna', 'plastikowe'): 0.14
# ('wielkość', 'liczba_pokoi') - ('rodzaj_i_rocznik', 'rok_budowy'): 0.14
# ('wielkość', 'liczba_pokoi') - ('wyposażenie', 'brak_informacji'): 0.13
# ('wycena', 'czynsz_całkowity') - ('wielkość', 'liczba_pięter_budynku'): 0.13
# ('wyposażenie', 'kuchenka') - ('materiał_budowlany', 'beton_komórkowy'): 0.13
# ('wyposażenie', 'kuchenka') - ('informacje_dodatkowe', 'klimatyzacja'): 0.13
# ('wyposażenie', 'lodówka') - ('materiał_budowlany', 'beton_komórkowy'): 0.13
# ('wyposażenie', 'lodówka') - ('materiał_budowlany', 'wielka_płyta'): 0.13
# ('wyposażenie', 'lodówka') - ('informacje_dodatkowe', 'klimatyzacja'): 0.13
# ('udogodnienia', 'miejsce_parkingowe') - ('media_komunikacyjne', 'internet'): 0.13
# ('wyposażenie', 'kuchenka') - ('materiał_budowlany', 'wielka_płyta'): 0.13
# ('udogodnienia', 'miejsce_parkingowe') - ('informacje_dodatkowe', 'brak_informacji'): 0.13
# ('wyposażenie', 'kuchenka') - ('bezpieczeństwo', 'system_alarmowy'): 0.13
# ('wyposażenie', 'lodówka') - ('bezpieczeństwo', 'system_alarmowy'): 0.13
# ('materiał_budowlany', 'cegła') - ('informacje_dodatkowe', 'brak_informacji'): 0.13
# ('wielkość', 'metry_kwadratowe') - ('udogodnienia', 'winda'): 0.13
# ('wycena', 'proporcja_kaucji') - ('wielkość', 'liczba_pokoi'): 0.13
# ('bezpieczeństwo', 'teren_ogrodzony') - ('okna', 'plastikowe'): 0.13
# ('okna', 'plastikowe') - ('materiał_budowlany', 'inny'): 0.13
# ('okna', 'plastikowe') - ('materiał_budowlany', 'pustak'): 0.13
# ('bezpieczeństwo', 'rolety_antywłamaniowe') - ('okna', 'plastikowe'): 0.13
# ('wycena', 'czynsz_za_metr') - ('informacje_dodatkowe', 'brak_informacji'): 0.13
# ('wyposażenie', 'telewizor') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.13
# ('ogrzewanie', 'brak_informacji') - ('materiał_budowlany', 'pustak'): 0.13
# ('ogrzewanie', 'brak_informacji') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.13
# ('media_komunikacyjne', 'telewizja_kablowa') - ('bezpieczeństwo', 'teren_ogrodzony'): 0.13
# ('wyposażenie', 'brak_informacji') - ('ogrzewanie', 'elektryczne'): 0.13
# ('media_komunikacyjne', 'telewizja_kablowa') - ('materiał_budowlany', 'inny'): 0.13
# ('wycena', 'czynsz') - ('materiał_budowlany', 'wielka_płyta'): 0.13
# ('wielkość', 'piętro') - ('media_komunikacyjne', 'internet'): 0.13
# ('wielkość', 'metry_kwadratowe') - ('media_komunikacyjne', 'telewizja_kablowa'): 0.13
# ('wyposażenie', 'meble') - ('materiał_budowlany', 'beton_komórkowy'): 0.13
# ('wyposażenie', 'meble') - ('informacje_dodatkowe', 'klimatyzacja'): 0.13
# ('wyposażenie', 'meble') - ('bezpieczeństwo', 'system_alarmowy'): 0.13
# ('wyposażenie', 'meble') - ('ogrzewanie', 'inne'): 0.12
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('materiał_budowlany', 'wielka_płyta'): 0.12
# ('udogodnienia', 'miejsce_parkingowe') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.12
# ('udogodnienia', 'winda') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): 0.12
# ('bezpieczeństwo', 'brak_informacji') - ('okna', 'brak_informacji'): 0.12
# ('media_komunikacyjne', 'telewizja_kablowa') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): 0.12
# ('okna', 'plastikowe') - ('materiał_budowlany', 'wielka_płyta'): 0.12
# ('wyposażenie', 'zmywarka') - ('okna', 'plastikowe'): 0.12
# ('wycena', 'czynsz_za_metr') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.12
# ('wyposażenie', 'meble') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): 0.12
# ('wycena', 'czynsz_za_metr') - ('udogodnienia', 'miejsce_parkingowe'): 0.12
# ('wielkość', 'liczba_pokoi') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): 0.12
# ('wielkość', 'liczba_pokoi') - ('udogodnienia', 'winda'): 0.12
# ('wycena', 'proporcja_kaucji') - ('ogrzewanie', 'inne'): 0.12
# ('wycena', 'proporcja_kaucji') - ('materiał_budowlany', 'wielka_płyta'): 0.12
# ('wielkość', 'liczba_pięter_budynku') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): 0.12
# ('wycena', 'proporcja_kaucji') - ('informacje_dodatkowe', 'piwnica'): 0.12
# ('wycena', 'cena') - ('informacje_dodatkowe', 'brak_informacji'): 0.12
# ('wycena', 'cena') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): 0.11
# ('wycena', 'czynsz_za_metr') - ('materiał_budowlany', 'beton_komórkowy'): 0.11
# ('wycena', 'czynsz_za_metr') - ('informacje_dodatkowe', 'klimatyzacja'): 0.11
# ('wycena', 'cena') - ('wyposażenie', 'meble'): 0.11
# ('wycena', 'czynsz_całkowity') - ('ogrzewanie', 'miejskie'): 0.1
# ('media_komunikacyjne', 'internet') - ('ogrzewanie', 'miejskie'): 0.1
# ('wycena', 'kaucja') - ('wyposażenie', 'telewizor'): 0.1
# ...
# ('wycena', 'proporcja_kaucji') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): -0.15
# ('wycena', 'cena') - ('materiał_budowlany', 'wielka_płyta'): -0.15
# ('wyposażenie', 'pralka') - ('okna', 'brak_informacji'): -0.15
# ('wielkość', 'metry_kwadratowe') - ('materiał_budowlany', 'pustak'): -0.15
# ('wielkość', 'piętro') - ('materiał_budowlany', 'cegła'): -0.15
# ('wielkość', 'piętro') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): -0.15
# ('wielkość', 'metry_kwadratowe') - ('wyposażenie', 'kuchenka'): -0.15
# ('wycena', 'czynsz_za_metr') - ('wielkość', 'liczba_pokoi'): -0.15
# ('wyposażenie', 'brak_informacji') - ('bezpieczeństwo', 'teren_ogrodzony'): -0.16
# ('wyposażenie', 'brak_informacji') - ('materiał_budowlany', 'inny'): -0.16
# ('wyposażenie', 'brak_informacji') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): -0.16
# ('wyposażenie', 'brak_informacji') - ('materiał_budowlany', 'pustak'): -0.16
# ('media_komunikacyjne', 'telewizja_kablowa') - ('ogrzewanie', 'elektryczne'): -0.16
# ('ogrzewanie', 'brak_informacji') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): -0.16
# ('ogrzewanie', 'brak_informacji') - ('materiał_budowlany', 'inny'): -0.16
# ('ogrzewanie', 'brak_informacji') - ('ogrzewanie', 'elektryczne'): -0.16
# ('media_komunikacyjne', 'telewizja_kablowa') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): -0.16
# ('media_komunikacyjne', 'telewizja_kablowa') - ('materiał_budowlany', 'pustak'): -0.16
# ('wycena', 'proporcja_kaucji') - ('udogodnienia', 'winda'): -0.16
# ('wycena', 'proporcja_kaucji') - ('materiał_budowlany', 'pustak'): -0.16
# ('wycena', 'czynsz_całkowity') - ('wielkość', 'piętro'): -0.16
# ('bezpieczeństwo', 'brak_informacji') - ('bezpieczeństwo', 'system_alarmowy'): -0.16
# ('bezpieczeństwo', 'brak_informacji') - ('materiał_budowlany', 'beton_komórkowy'): -0.16
# ('bezpieczeństwo', 'brak_informacji') - ('informacje_dodatkowe', 'klimatyzacja'): -0.16
# ('media_komunikacyjne', 'brak_informacji') - ('ogrzewanie', 'miejskie'): -0.16
# ('wycena', 'czynsz') - ('wyposażenie', 'meble'): -0.16
# ('wielkość', 'piętro') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.16
# ('udogodnienia', 'winda') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.16
# ('okna', 'brak_informacji') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.16
# ('informacje_dodatkowe', 'oddzielna_kuchnia') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.16
# ('wyposażenie', 'meble') - ('materiał_budowlany', 'cegła'): -0.17
# ('wycena', 'kaucja') - ('wielkość', 'liczba_pięter_budynku'): -0.17
# ('wycena', 'czynsz_całkowity') - ('wycena', 'proporcja_kaucji'): -0.17
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('materiał_budowlany', 'cegła'): -0.17
# ('wycena', 'proporcja_kaucji') - ('bezpieczeństwo', 'teren_ogrodzony'): -0.17
# ('wycena', 'czynsz') - ('wielkość', 'liczba_pięter_budynku'): -0.17
# ('wyposażenie', 'meble') - ('materiał_budowlany', 'brak_informacji'): -0.17
# ('media_komunikacyjne', 'telefon') - ('materiał_budowlany', 'cegła'): -0.18
# ('wycena', 'czynsz') - ('materiał_budowlany', 'inny'): -0.18
# ('media_komunikacyjne', 'brak_informacji') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.18
# ('wycena', 'czynsz') - ('materiał_budowlany', 'cegła'): -0.18
# ('media_komunikacyjne', 'brak_informacji') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): -0.18
# ('media_komunikacyjne', 'brak_informacji') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): -0.18
# ('ogrzewanie', 'elektryczne') - ('okna', 'plastikowe'): -0.18
# ('materiał_budowlany', 'wielka_płyta') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.18
# ('wyposażenie', 'telewizor') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.18
# ('udogodnienia', 'winda') - ('materiał_budowlany', 'wielka_płyta'): -0.18
# ('wycena', 'cena') - ('wycena', 'czynsz'): -0.18
# ('wycena', 'czynsz_za_metr') - ('media_komunikacyjne', 'brak_informacji'): -0.18
# ('media_komunikacyjne', 'internet') - ('ogrzewanie', 'brak_informacji'): -0.18
# ('wielkość', 'metry_kwadratowe') - ('ogrzewanie', 'inne'): -0.18
# ('wyposażenie', 'brak_informacji') - ('okna', 'plastikowe'): -0.18
# ('wyposażenie', 'piekarnik') - ('ogrzewanie', 'inne'): -0.18
# ('wyposażenie', 'piekarnik') - ('materiał_budowlany', 'beton_komórkowy'): -0.18
# ('wyposażenie', 'piekarnik') - ('informacje_dodatkowe', 'klimatyzacja'): -0.18
# ('ogrzewanie', 'inne') - ('ogrzewanie', 'miejskie'): -0.18
# ('ogrzewanie', 'inne') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): -0.18
# ('ogrzewanie', 'miejskie') - ('bezpieczeństwo', 'system_alarmowy'): -0.18
# ('ogrzewanie', 'miejskie') - ('materiał_budowlany', 'beton_komórkowy'): -0.18
# ('ogrzewanie', 'miejskie') - ('informacje_dodatkowe', 'klimatyzacja'): -0.18
# ('wielkość', 'piętro') - ('wyposażenie', 'brak_informacji'): -0.19
# ('wyposażenie', 'brak_informacji') - ('materiał_budowlany', 'wielka_płyta'): -0.19
# ('wyposażenie', 'telewizor') - ('ogrzewanie', 'brak_informacji'): -0.19
# ('wyposażenie', 'zmywarka') - ('ogrzewanie', 'brak_informacji'): -0.19
# ('wielkość', 'metry_kwadratowe') - ('bezpieczeństwo', 'brak_informacji'): -0.19
# ('wielkość', 'metry_kwadratowe') - ('wyposażenie', 'telewizor'): -0.19
# ('media_komunikacyjne', 'internet') - ('ogrzewanie', 'elektryczne'): -0.19
# ('materiał_budowlany', 'inny') - ('informacje_dodatkowe', 'brak_informacji'): -0.19
# ('wycena', 'cena') - ('okna', 'plastikowe'): -0.19
# ('ogrzewanie', 'gazowe') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.19
# ('ogrzewanie', 'gazowe') - ('okna', 'brak_informacji'): -0.19
# ('media_komunikacyjne', 'internet') - ('materiał_budowlany', 'cegła'): -0.19
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('informacje_dodatkowe', 'brak_informacji'): -0.19
# ('wyposażenie', 'brak_informacji') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.19
# ('udogodnienia', 'winda') - ('media_komunikacyjne', 'telewizja_kablowa'): -0.19
# ('ogrzewanie', 'brak_informacji') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.19
# ('wycena', 'cena') - ('wycena', 'proporcja_kaucji'): -0.19
# ('wielkość', 'metry_kwadratowe') - ('wyposażenie', 'meble'): -0.19
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('materiał_budowlany', 'cegła'): -0.2
# ('materiał_budowlany', 'cegła') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): -0.2
# ('wyposażenie', 'telewizor') - ('materiał_budowlany', 'brak_informacji'): -0.2
# ('wycena', 'cena') - ('wielkość', 'piętro'): -0.2
# ('wycena', 'proporcja_kaucji') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): -0.2
# ('wycena', 'kaucja') - ('ogrzewanie', 'miejskie'): -0.2
# ('wycena', 'czynsz') - ('ogrzewanie', 'inne'): -0.2
# ('wyposażenie', 'pralka') - ('ogrzewanie', 'inne'): -0.21
# ('wycena', 'proporcja_kaucji') - ('ogrzewanie', 'miejskie'): -0.21
# ('wielkość', 'piętro') - ('rodzaj_i_rocznik', 'rok_budowy'): -0.21
# ('wycena', 'czynsz_za_metr') - ('wycena', 'proporcja_kaucji'): -0.21
# ('wyposażenie', 'telewizor') - ('ogrzewanie', 'gazowe'): -0.21
# ('media_komunikacyjne', 'telefon') - ('materiał_budowlany', 'wielka_płyta'): -0.21
# ('ogrzewanie', 'gazowe') - ('materiał_budowlany', 'wielka_płyta'): -0.21
# ('ogrzewanie', 'miejskie') - ('bezpieczeństwo', 'brak_informacji'): -0.21
# ('wycena', 'proporcja_kaucji') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): -0.21
# ('bezpieczeństwo', 'brak_informacji') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): -0.22
# ('ogrzewanie', 'elektryczne') - ('informacje_dodatkowe', 'piwnica'): -0.22
# ('bezpieczeństwo', 'rolety_antywłamaniowe') - ('materiał_budowlany', 'brak_informacji'): -0.22
# ('bezpieczeństwo', 'rolety_antywłamaniowe') - ('informacje_dodatkowe', 'piwnica'): -0.22
# ('materiał_budowlany', 'brak_informacji') - ('materiał_budowlany', 'inny'): -0.22
# ('materiał_budowlany', 'brak_informacji') - ('materiał_budowlany', 'pustak'): -0.22
# ('materiał_budowlany', 'pustak') - ('informacje_dodatkowe', 'piwnica'): -0.22
# ('bezpieczeństwo', 'teren_ogrodzony') - ('informacje_dodatkowe', 'piwnica'): -0.22
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.22
# ('okna', 'brak_informacji') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): -0.22
# ('media_komunikacyjne', 'brak_informacji') - ('materiał_budowlany', 'beton_komórkowy'): -0.22
# ('media_komunikacyjne', 'brak_informacji') - ('informacje_dodatkowe', 'klimatyzacja'): -0.22
# ('wielkość', 'liczba_pokoi') - ('wielkość', 'liczba_pięter_budynku'): -0.22
# ('wycena', 'czynsz') - ('bezpieczeństwo', 'brak_informacji'): -0.22
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('materiał_budowlany', 'cegła'): -0.22
# ('media_komunikacyjne', 'telewizja_kablowa') - ('ogrzewanie', 'brak_informacji'): -0.22
# ('ogrzewanie', 'brak_informacji') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): -0.22
# ('wyposażenie', 'brak_informacji') - ('ogrzewanie', 'miejskie'): -0.22
# ('wielkość', 'metry_kwadratowe') - ('wielkość', 'piętro'): -0.22
# ('okna', 'plastikowe') - ('informacje_dodatkowe', 'brak_informacji'): -0.22
# ('wyposażenie', 'lodówka') - ('okna', 'brak_informacji'): -0.22
# ('wycena', 'czynsz') - ('ogrzewanie', 'elektryczne'): -0.23
# ('wielkość', 'piętro') - ('materiał_budowlany', 'beton_komórkowy'): -0.23
# ('wielkość', 'piętro') - ('informacje_dodatkowe', 'klimatyzacja'): -0.23
# ('wielkość', 'piętro') - ('bezpieczeństwo', 'system_alarmowy'): -0.23
# ('wyposażenie', 'brak_informacji') - ('media_komunikacyjne', 'telefon'): -0.23
# ('wyposażenie', 'brak_informacji') - ('ogrzewanie', 'gazowe'): -0.23
# ('ogrzewanie', 'brak_informacji') - ('ogrzewanie', 'gazowe'): -0.23
# ('wielkość', 'piętro') - ('ogrzewanie', 'elektryczne'): -0.23
# ('wycena', 'proporcja_kaucji') - ('media_komunikacyjne', 'telefon'): -0.23
# ('wielkość', 'metry_kwadratowe') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.23
# ('bezpieczeństwo', 'brak_informacji') - ('bezpieczeństwo', 'teren_ogrodzony'): -0.23
# ('bezpieczeństwo', 'brak_informacji') - ('materiał_budowlany', 'inny'): -0.23
# ('bezpieczeństwo', 'brak_informacji') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): -0.23
# ('bezpieczeństwo', 'brak_informacji') - ('materiał_budowlany', 'pustak'): -0.23
# ('wielkość', 'piętro') - ('materiał_budowlany', 'brak_informacji'): -0.23
# ('wyposażenie', 'telewizor') - ('bezpieczeństwo', 'brak_informacji'): -0.23
# ('wyposażenie', 'kuchenka') - ('ogrzewanie', 'inne'): -0.23
# ('wyposażenie', 'lodówka') - ('ogrzewanie', 'inne'): -0.23
# ('wielkość', 'liczba_pokoi') - ('ogrzewanie', 'brak_informacji'): -0.24
# ('media_komunikacyjne', 'internet') - ('okna', 'brak_informacji'): -0.24
# ('wyposażenie', 'piekarnik') - ('okna', 'brak_informacji'): -0.24
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('okna', 'brak_informacji'): -0.24
# ('ogrzewanie', 'miejskie') - ('okna', 'brak_informacji'): -0.24
# ('wielkość', 'liczba_pokoi') - ('materiał_budowlany', 'wielka_płyta'): -0.24
# ('wielkość', 'liczba_pokoi') - ('wyposażenie', 'telewizor'): -0.24
# ('informacje_dodatkowe', 'brak_informacji') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.24
# ('bezpieczeństwo', 'monitoring_lub_ochrona') - ('materiał_budowlany', 'wielka_płyta'): -0.24
# ('wycena', 'proporcja_kaucji') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): -0.24
# ('wycena', 'proporcja_kaucji') - ('materiał_budowlany', 'inny'): -0.24
# ('wycena', 'proporcja_kaucji') - ('okna', 'plastikowe'): -0.24
# ('wielkość', 'liczba_pokoi') - ('bezpieczeństwo', 'brak_informacji'): -0.24
# ('rodzaj_i_rocznik', 'rok_budowy') - ('materiał_budowlany', 'inny'): -0.24
# ('wielkość', 'liczba_pokoi') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.24
# ('udogodnienia', 'miejsce_parkingowe') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.24
# ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe') - ('okna', 'brak_informacji'): -0.24
# ('materiał_budowlany', 'cegła') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.24
# ('udogodnienia', 'miejsce_parkingowe') - ('informacje_dodatkowe', 'piwnica'): -0.25
# ('wyposażenie', 'brak_informacji') - ('informacje_dodatkowe', 'piwnica'): -0.25
# ('ogrzewanie', 'brak_informacji') - ('informacje_dodatkowe', 'piwnica'): -0.25
# ('wycena', 'czynsz') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): -0.25
# ('wielkość', 'liczba_pięter_budynku') - ('media_komunikacyjne', 'telefon'): -0.25
# ('wielkość', 'liczba_pięter_budynku') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): -0.26
# ('wycena', 'czynsz_za_metr') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.26
# ('wyposażenie', 'brak_informacji') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): -0.26
# ('ogrzewanie', 'brak_informacji') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): -0.26
# ('wycena', 'czynsz') - ('wyposażenie', 'telewizor'): -0.26
# ('wielkość', 'liczba_pięter_budynku') - ('ogrzewanie', 'brak_informacji'): -0.26
# ('wyposażenie', 'piekarnik') - ('ogrzewanie', 'elektryczne'): -0.26
# ('ogrzewanie', 'elektryczne') - ('ogrzewanie', 'miejskie'): -0.26
# ('ogrzewanie', 'miejskie') - ('bezpieczeństwo', 'teren_ogrodzony'): -0.26
# ('ogrzewanie', 'miejskie') - ('bezpieczeństwo', 'rolety_antywłamaniowe'): -0.26
# ('ogrzewanie', 'miejskie') - ('materiał_budowlany', 'pustak'): -0.26
# ('ogrzewanie', 'elektryczne') - ('bezpieczeństwo', 'domofon_lub_wideodomofon'): -0.26
# ('wyposażenie', 'meble') - ('okna', 'brak_informacji'): -0.26
# ('ogrzewanie', 'miejskie') - ('bezpieczeństwo', 'monitoring_lub_ochrona'): -0.27
# ('media_komunikacyjne', 'internet') - ('materiał_budowlany', 'brak_informacji'): -0.27
# ('media_komunikacyjne', 'brak_informacji') - ('okna', 'plastikowe'): -0.27
# ('udogodnienia', 'miejsce_parkingowe') - ('wyposażenie', 'telewizor'): -0.27
# ('udogodnienia', 'miejsce_parkingowe') - ('materiał_budowlany', 'wielka_płyta'): -0.27
# ('wyposażenie', 'zmywarka') - ('materiał_budowlany', 'cegła'): -0.27
# ('materiał_budowlany', 'cegła') - ('materiał_budowlany', 'wielka_płyta'): -0.27
# ('wyposażenie', 'telewizor') - ('materiał_budowlany', 'cegła'): -0.27
# ('media_komunikacyjne', 'brak_informacji') - ('materiał_budowlany', 'wielka_płyta'): -0.27
# ('wyposażenie', 'telewizor') - ('media_komunikacyjne', 'brak_informacji'): -0.27
# ('media_komunikacyjne', 'brak_informacji') - ('ogrzewanie', 'gazowe'): -0.27
# ('wielkość', 'liczba_pokoi') - ('media_komunikacyjne', 'brak_informacji'): -0.27
# ('bezpieczeństwo', 'domofon_lub_wideodomofon') - ('materiał_budowlany', 'brak_informacji'): -0.27
# ('udogodnienia', 'winda') - ('informacje_dodatkowe', 'piwnica'): -0.27
# ('wielkość', 'liczba_pięter_budynku') - ('udogodnienia', 'miejsce_parkingowe'): -0.27
# ('udogodnienia', 'miejsce_parkingowe') - ('bezpieczeństwo', 'brak_informacji'): -0.27
# ('ogrzewanie', 'miejskie') - ('informacje_dodatkowe', 'brak_informacji'): -0.28
# ('wycena', 'cena') - ('bezpieczeństwo', 'brak_informacji'): -0.28
# ('wycena', 'czynsz_całkowity') - ('media_komunikacyjne', 'brak_informacji'): -0.28
# ('wyposażenie', 'zmywarka') - ('informacje_dodatkowe', 'brak_informacji'): -0.28
# ('media_komunikacyjne', 'telefon') - ('informacje_dodatkowe', 'brak_informacji'): -0.28
# ('rodzaj_i_rocznik', 'rok_budowy') - ('media_komunikacyjne', 'brak_informacji'): -0.28
# ('wielkość', 'piętro') - ('informacje_dodatkowe', 'tylko_dla_niepalących'): -0.28
# ('wycena', 'czynsz') - ('media_komunikacyjne', 'brak_informacji'): -0.29
# ('wielkość', 'liczba_pięter_budynku') - ('materiał_budowlany', 'beton_komórkowy'): -0.29
# ('wielkość', 'liczba_pięter_budynku') - ('informacje_dodatkowe', 'klimatyzacja'): -0.29
# ('wielkość', 'liczba_pięter_budynku') - ('ogrzewanie', 'elektryczne'): -0.29
# ('bezpieczeństwo', 'brak_informacji') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.29
# ('udogodnienia', 'winda') - ('bezpieczeństwo', 'brak_informacji'): -0.29
# ('wyposażenie', 'brak_informacji') - ('bezpieczeństwo', 'drzwi_lub_okna_antywłamaniowe'): -0.29
# ('wycena', 'cena') - ('informacje_dodatkowe', 'oddzielna_kuchnia'): -0.29
# ('wycena', 'proporcja_kaucji') - ('informacje_dodatkowe', 'pomieszczenie_gospodarcze'): -0.29
# ('wyposażenie', 'telewizor') - ('okna', 'brak_informacji'): -0.29
# ('wyposażenie', 'kuchenka') - ('materiał_budowlany', 'cegła'): -0.3
# ('wyposażenie', 'lodówka') - ('materiał_budowlany', 'cegła'): -0.3
# ('wycena', 'czynsz_za_metr') - ('materiał_budowlany', 'cegła'): -0.3

# %% [markdown]
# **Wnioski z innych korelacji:**
#
# 1. **Cena najmu jako główny koszt**:<br>
# Prawie doskonała korelacja (`0.98`) między `'ceną najmu'` a `'całkowitym czynszem'` wskazuje, że cena najmu konsekwentnie przyczynia się do całkowitego kosztu wynajmu, a w mniejszym stopniu koszty dodatkowe jak np. `czynsz` dla spółdzielni.
#
# 1. **Kompletne wyposażenie**:<br>
# Wyraźne powiązania między elementami wyposażenia, takimi jak `kuchenka`, `lodówka`, `pralka` i `piekarnik` (korelacje od `0.78` do `0.89`), pokazują, że te urządzenia często są oferowane razem w ofertach wynajmu. Jeśli mieszkanie posiada jedno z tych urządzeń, zwykle ma też pozostałe.
#
# 1. **Wyposażenie a bezpieczeństwo**:<br>
# Umiarkowana pozytywna zależność (`0.68` do` 0.64`) między posiadaniem podstawowych sprzętów AGD (`kuchenka`, `lodówka`, `pralka`) a systemami bezpieczeństwa takimi jak `domofon` lub `wideodomofon`, sugeruje, że mieszkania z nowoczesnym wyposażeniem często kładą również nacisk na aspekty bezpieczeństwa.

# %% [markdown]
# ### 2.4 Cechy i wyposażenie

# %%
def display_category_proportions(data: pd.Series, title: str):

    # Calculate the percentage of each category
    category_percentage = data.value_counts(normalize=True) * 100

    # Create a bar plot
    fig, ax = plt.subplots(figsize=aesthetics_plots["figsize"]["multiplot"])
    my_palette = ['#bfed2d'] + ['#00c37f'] + ["#007e90"] + ['#51006f']*2

    unique_categories = data.unique()
    length = len(unique_categories)
    if (length - 5) <= 0:
        adjusted_length = 1
    else:
        adjusted_length = length - 5
    my_palette = ['#bfed2d'] + ['#00c37f'] + ["#007e90"]*2 + ['#51006f']*adjusted_length

    # Make the index more readable
    more_readable_index = []
    for _index in category_percentage.index:
        more_readable_index.append(_index.replace('_', ' '))
    category_percentage.index = more_readable_index

    sns.barplot(x=category_percentage.index, y=category_percentage.values, ax=ax, palette=my_palette)
    
    # Add labels to the plot
    plt.title(title, color=aesthetics_plots['label_color'], fontsize=aesthetics_plots['title_size'], weight=aesthetics_plots['fontweight'])
    plt.xlabel('Kategoria', color=aesthetics_plots['label_color'], fontsize=aesthetics_plots['y_and_x_label_size'], weight=aesthetics_plots['fontweight'])
    plt.ylabel('Procent', color=aesthetics_plots['label_color'], fontsize=aesthetics_plots['y_and_x_label_size'], weight=aesthetics_plots['fontweight'])

    plt.xticks(color=aesthetics_plots['label_color'])
    plt.yticks(color=aesthetics_plots['label_color'])
    
    sns.despine(right=True, top=True)


    # Add percentage labels on the bars
    for p in ax.patches:
        ax.annotate(f"{p.get_height():.1f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', fontsize=12, color=aesthetics_plots['label_color'], xytext=(0, 5),
                    textcoords='offset points')

    # Display the plot
    plt.show()


display_category_proportions(offers_5km_df[('rodzaj_i_rocznik', 'typ_budynku')], "Rozkład procentowy kategorii")

# %%
show_categorical_data_percentage_distribution(
    offers_5km_df,  
    ('rodzaj_i_rocznik', 'typ_budynku'),
    ('rodzaj_i_rocznik', 'rok_budowy'),
    'Rozkład lat budowy dla każdego typu budynków'
    )

# %% [markdown]
# **Wnioski dotyczące typu budynku i roku budowy**:
#
# 1. **Blok mieszkalne**:<br>
# obejmujący `48,2%` zbioru danych, jest dominującą kategorią, wskazującą na silną preferencję dla ofert mieszkaniowych. Wybór ten jest powszechny zarówno w "historycznych obszarach miejskich", jak i w późniejszej erze, często charakteryzującej się "budownictwem wielkopłytowym" z czasów komunizmu, a także w nowszych inwestycjach, pokazując stałą podaż na tego typu mieszkania w różnych epokach.
#
# 1. **Trendy w urbanistyce**:<br>
# Znaczący wzrost budownictwa po roku `2000` wskazuje na wzrost dostępności nowszych rezydencji. Jednak `"domy szeregowe"` i `"domy wolnostojące"` stanowią odpowiednio tylko `0,3%` i `2,8%` typów mieszkań. Ten niedobór sugeruje trend rozwoju urbanistycznego, który faworyzuje budynki wielopiętrowe zamiast pojedynczych domów, wskazując na preferencję dla ekspansji pionowej w zabudowie mieszkaniowej.

# %%
def move_index_to_last(series, index_to_move):
    """
    Moves a specified index to the last position in a pandas Series.

    Args:
    series (pd.Series): The original series.
    index_to_move (str): The index to be moved to the last position.

    Returns:
    pd.Series: A new series with the specified index moved to the last position.
    """
    if index_to_move not in series.index:
        raise ValueError(f"Index '{index_to_move}' not found in the Series.")

    # Extracting the indices
    idx_list = series.index.tolist()

    # Remove the index to move and then append it at the end
    idx_list.remove(index_to_move)
    idx_list.append(index_to_move)

    # Reindexing the series
    return series.reindex(idx_list)

# %%
def visualize_true_percentage_by_category(df: pd.DataFrame, main_category: str):
    # Check if the DataFrame contains the main category
    if main_category not in df.columns.get_level_values(0):
        raise KeyError(f"Main category '{main_category}' not found in DataFrame.")

    # Extract subcategories for the given main category
    subcategories = [col for col in df.columns if col[0] == main_category]

    # Calculate percentage of True values for each subcategory
    percentages = {}
    for subcat in subcategories:
        percentages[subcat[1]] = (df[subcat].sum() / len(df)) * 100

    # Convert to Series for plotting
    category_percentage = pd.Series(percentages)

    # Sort by percentage, 'no_information' should be last
    category_percentage = category_percentage.sort_values(ascending=False)
    if 'brak_informacji' in category_percentage.index:
        category_percentage = move_index_to_last(category_percentage, 'brak_informacji')

    # Create a bar plot
    if category_percentage.index.__len__() >= 5:
        plot_size = aesthetics_plots["figsize"]["multiplot"]
    else:
        plot_size = aesthetics_plots["figsize"]["singleplot"]

    fig, ax = plt.subplots(figsize=plot_size)

    # Set the palette
    length = len(category_percentage.index)
    if (length - 5) <= 0:
        adjusted_length = 1
    else:
        adjusted_length = length - 5
    my_palette = ['#bfed2d'] + ['#00c37f'] + ["#007e90"]*2 + ['#51006f']*adjusted_length

    if 'brak_informacji' in category_percentage.index:
        my_palette = my_palette[:max(1, length - 1)] + ['#b3b3b3']

    more_readable_index = []
    for _index in category_percentage.index:
        more_readable_index.append(_index.replace('_', '\n'))

    category_percentage.index = more_readable_index

    sns.barplot(x=category_percentage.index, y=category_percentage.values, ax=ax, palette=my_palette)
    
    # Add labels to the plot
    title = main_category.replace('_', ' ').title()
    plt.title(title, color=aesthetics_plots['label_color'], fontsize=aesthetics_plots['title_size'], weight=aesthetics_plots['fontweight'])
    plt.xlabel('Kategoria', color=aesthetics_plots['label_color'], fontsize=aesthetics_plots['y_and_x_label_size'], weight=aesthetics_plots['fontweight'])
    plt.ylabel('Odestek (%)', color=aesthetics_plots['label_color'], fontsize=aesthetics_plots['y_and_x_label_size'], weight=aesthetics_plots['fontweight'])

    plt.xticks(color=aesthetics_plots['label_color'])
    plt.yticks(color=aesthetics_plots['label_color'])
    
    sns.despine(right=True, top=True)

    # Add percentage labels on the bars
    for p in ax.patches:
        ax.annotate(f"{p.get_height():.1f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', fontsize=12, color=aesthetics_plots['label_color'], xytext=(0, 5),
                    textcoords='offset points')

    # Display the plot
    plt.show()

visualize_true_percentage_by_category(offers_5km_df, 'udogodnienia')

# %% [markdown]
# **Wnioski udogodnienia**:
# 1. **Windy**:<br>
# są uwzględnione w `36,5%` ofert apartamentów.
# 1. **Miejsca parkingowe**:<br>
# są dostępne w `31,6%` ofert.

# %%
visualize_true_percentage_by_category(offers_5km_df, 'wyposażenie')

# %% [markdown]
# **Wnioski wyposażenie**:
#
# 1. **Trendy w wyposażeniu mieszkań**:<br>
# Meble znajdują się w `65,8%` mieszkań, podczas gdy `lodówki` i `kuchenki` są obecne odpowiednio w `54%` i `52,3%` ofert, a `pralki` znajdują się dokładnie w `połowie` ofert. Wskazuje to na skłonność do wyposażania mieszkań w niezbędne urządzenia dla najemców poszukujących nieruchomości gotowych do zamieszkania.
# 1. **Rzadsze udogodnienia**:<br>
# Obecność `telewizorów` w `25,1%` i `zmywarek` w `31,7%` ofert pokazuje, że są one mniej powszechne, prawdopodobnie i są uważane za nieistotne.

# %%
visualize_true_percentage_by_category(offers_5km_df, 'media_komunikacyjne')

# %% [markdown]
# **Wnioski usługi multimedialne**:
# 1. **Powszechność**:<br>
# `Dostęp do Internetu` jest wymieniony w `40,9%` ofert i `32,0%` dla `telewizji kablowej`.
# 1. **Brak informacji**:<br>
# `Brak informacji` o typach mediów jest zgłaszany w `56,8%` ofert, co pokazuje, że dla większości są to nieistotne informacje.

# %%
visualize_true_percentage_by_category(offers_5km_df, 'ogrzewanie')

# %% [markdown]
# **Wnioski dotyczące ogrzewania**:
#
# 1. **Ogrzewanie miejskie**:<br>
# jest najczęściej zgłaszanym typem (`61,6%`).
# 1. **Inne ogrzewanie**:<br>
# Ogrzewanie gazowe (`11,3%`), a zwłaszcza `elektryczne` (`3,6%`) jest mało spotykane głównie ze względu na wysokie koszty.

# %%
visualize_true_percentage_by_category(offers_5km_df, 'bezpieczeństwo')

# %% [markdown]
# **Wnioski dotyczące zabezpieczeń**:
#
# 1. **Systemy Domofonowe:**:<br>
# `Systemy domofonowe` lub `wideodomofonowe` są wymienione w `51,2%` ofert, co świadczy o ich powszechnym występowaniu.
# 1. **Zaawansowanych Zabezpieczeń**:<br>
# Bardziej zaawansowane funkcje bezpieczeństwa, takie jak `systemy alarmowe`, są wspomniane tylko w `2,6%` ofert, a rolety antywłamaniowe w `3,0%`, co sugeruje, że mogą być one rzadziej spotykane lub wyróżniane wyłącznie w ofertach premium.

# %%
visualize_true_percentage_by_category(offers_5km_df, 'okna')

# %% [markdown]
# **Wnioski okna**:
#
# 1. **Plastik**:<br>
# Okna `plastikowe` dominują w cechach na poziomie `71,5%`.
# 1. **Brak informacji**:<br>
# Zauważalny jest "brak informacji" w `25,8%` ofert dotyczących typów okien.

# %%
visualize_true_percentage_by_category(offers_5km_df, 'materiał_budowlany')

# %% [markdown]
# **Wnioski materiał budowlany**:
#
# 1. **Cegła**:<br>
# jest określona w `25,2%` nieruchomości.
# 1. **Wielka płyta**:<br>
# jest wymieniany w `10,8%`, ale wynik może być mniejszy przez niewymienienie go ze względu na niepopularność wśród potencjalnych najemców.
# 1. **Brak informacji**:<br>
# Prawie połowa ofert, `49,6%`, nie ujawnia materiału budowlanego.

# %%
visualize_true_percentage_by_category(offers_5km_df, 'informacje_dodatkowe')

# %% [markdown]
# **Wnioski dodatkowe informacje**:
# 1. **Częste**:<br>
# `Oddzielna kuchnia` i `piwnica` to odpowiednio `30,0%` i `28,4%` ofert.
#
# 1. **Rzadkie**:<br>
# Mniejszy, ale znaczący odsetek ofert określa `tylko dla niepalących` (13,9%) oraz `pomieszczenie gospodarcze` (12,8%).
#
# 1. **Bardzo rzadkie**:<br>
# `Klimatyzacja` i `duplex` są rzadkie, odpowiednio `8,7%` i `0,6%`, co może sugerować, że te cechy są niestandardowe. Przeważająca liczba ofert `(39,4%) `nie dostarcza żadnych dodatkowych informacji`.
